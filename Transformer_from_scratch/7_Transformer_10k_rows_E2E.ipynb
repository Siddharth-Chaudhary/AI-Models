# %% [markdown]
# ## Motivation for Attention

# %% [raw]
# RNN, suffers from two disadnavtages,
# 1 Trains very slow
# 2 Vectors generated truely doesnt represent the actual context of the word, In rn we get signals from the word coming just before that word, Even in birectional RANs, kind of suffer from the issue they just look left to write and write to left context seperately and then concatenate them. so the true meaning is kind lost.
# ONE way to improves the vector generation is via some attention mechanism.

# %%
import numpy as np 
import pandas as pd 
import string
from string import digits 
import re 
import torch
from torch import nn 
import torch.nn.functional as nnfunc 
import math 
import contractions 
import gc

# %%
# What version of Python do you have?
import sys 
import platform
import sklearn as sk 
from torch.utils.data import Dataset, DataLoader
print(f"python Platform: {platform.platform()}")
print(f"PyTorch Version: {torch.__version__}")
print(f"Python: {sys.version}")
print(f"Pandas: {pd.__version__}")
print(f"Scikit-Learn: {sk.__version__}")
# Out:
# python Platform: macOS-15.4-arm64-arm-64bit
# PyTorch Version: 2.6.0
# Python: 3.11.7 (main, Dec 15 2023, 12:09:56) [Clang 14.0.6 ]
# Pandas: 2.2.3
# Scikit-Learn: 1.6.1

# %%
def get_device():
    has_gpu = torch.cuda.is_available()
    has_mps = torch.backends.mps.is_built()
    print ("NVIDIA/CUDA GPU is", "available" if has_gpu else "NOT AVAILABLE")
    print("MPS (Apple Metal) is", "AVAILABLE" if has_mps else "NOT AVAILABLE")
    return torch.device('mps') if has_mps else torch.device('cuda') if has_gpu else torch.device('cpu')
device = get_device()
print(f"Target device is {device}")
# Out:
# NVIDIA/CUDA GPU is NOT AVAILABLE
# MPS (Apple Metal) is AVAILABLE
# Target device is mps

# %%
def scaled_dot_product(q, k, v, mask=None):
    d_k = q.size()[-1]
    scaled = torch.matmul(q, k.transpose(-1, -2)) / math.sqrt(d_k) 
    if mask is not None:
        scaled = scaled.permute(1, 0, 2, 3) + mask
        scaled = scaled.permute(1, 0, 2, 3)
    attention = nnfunc.softmax(scaled, dim=-1)
    values = torch.matmul(attention, v)
    return values, attention

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_sequence_length):
        super().__init__()
        self.max_sequence_length = max_sequence_length
        self.d_model = d_model
        
    def forward(self):
        even_i = torch.arange(0, self.d_model, 2).float()
        denominator = torch.pow(10000, even_i/self.d_model)
        position = (torch.arange(self.max_sequence_length).reshape(self.max_sequence_length, 1))
        even_PE = torch.sin(position / denominator)
        odd_PE = torch.cos(position / denominator)
        stacked = torch.stack([even_PE, odd_PE], dim=2)
        PE = torch.flatten(stacked, start_dim=1, end_dim=2)
        return PE

# %%
class SentenceEmbedding(nn.Module):
    "For a given sentence, create an embedding" 
    def __init__(self, max_sequence_length, d_model, language_to_index, START_TOKEN, END_TOKEN, PADDING_TOKEN):
        super().__init__()
        self.vocab_size = len(language_to_index)
        self.max_sequence_length = max_sequence_length
        self.embedding = nn.Embedding (self.vocab_size, d_model)
        self.language_to_index = language_to_index
        self.position_encoder = PositionalEncoding(d_model, max_sequence_length)
        self.dropout = nn.Dropout(p=0.1)
        self.START_TOKEN = START_TOKEN
        self.END_TOKEN = END_TOKEN
        self.PADDING_TOKEN = PADDING_TOKEN
        print(self.embedding.weight.shape)

    def batch_tokenize(self, batch, start_token, end_token):
        def tokenize(sentence, start_token, end_token):
            sentence_word_indices = []
            for token in sentence.split():
                if token in self.language_to_index:
                    sentence_word_indices.append(self.language_to_index[token])
            if start_token:
                sentence_word_indices.insert(0, self.language_to_index[self.START_TOKEN])
            if end_token:
                sentence_word_indices.append(self.language_to_index[self.END_TOKEN]) 
            for _ in range(len(sentence_word_indices), self.max_sequence_length):
                sentence_word_indices.append(self.language_to_index[self.PADDING_TOKEN])
            return torch.tensor(sentence_word_indices)
            
        tokenized = []
        for sentence_num in range(len(batch)):
            tokenized.append(tokenize(batch[sentence_num], start_token, end_token))
        tokenized = torch.stack(tokenized)
        return tokenized.to(device)
            
    def forward(self, x, start_token, end_token): # sentence
        x = self.batch_tokenize(x, start_token, end_token)
        x = self.embedding(x)
        pos = self.position_encoder().to(device)
        x = self.dropout(x + pos) 
        return x

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super().__init__()
        self.d_model = d_model
        self.num_heads = num_heads
        self.head_dim = d_model // num_heads
        self.qkv_layer = nn.Linear(d_model, 3 * d_model)
        self.linear_layer = nn.Linear(d_model, d_model)
        
    def forward(self, x, mask):
        batch_size, sequence_length, d_model = x.size()
        qkv = self.qkv_layer(x)
        qkv = qkv.reshape(batch_size, sequence_length, self.num_heads, 3 * self.head_dim)
        qkv = qkv.permute(0, 2, 1, 3)
        q, k, v = qkv.chunk(3, dim=-1)
        values, attention = scaled_dot_product(q, k, v, mask)
        values = values.permute(0, 2, 1, 3).reshape(batch_size, sequence_length, self.num_heads * self.head_dim)
        out = self.linear_layer(values)
        return out

# %%
class LayerNormalization(nn.Module):
    def __init__(self, parameters_shape, eps=1e-5):
        super().__init__()
        self.parameters_shape=parameters_shape 
        self.eps=eps
        self.gamma = nn.Parameter(torch.ones(parameters_shape))
        self.beta = nn.Parameter(torch.zeros(parameters_shape))
    
    def forward(self, inputs):
        dims = [-(i + 1) for i in range(len(self.parameters_shape))]
        mean = inputs.mean(dim=dims, keepdim=True)
        var = ((inputs - mean) ** 2).mean(dim=dims, keepdim=True)
        std = (var + self.eps).sqrt()
        y = (inputs - mean) / std
        out = self.gamma * y + self.beta
        return out

# %%
class PositionwiseFeedForward(nn.Module):
    def __init__(self, d_model, hidden, drop_prob=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.linear1 = nn.Linear(d_model, hidden)
        self.linear2 = nn.Linear (hidden, d_model)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=drop_prob)
    
    def forward(self, x) :
        x = self.linear1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear2(x)
        return x

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, ffn_hidden, num_heads, drop_prob):
        super(EncoderLayer, self).__init__()
        self.attention = MultiHeadAttention(d_model=d_model, num_heads=num_heads)
        self.norm1 = LayerNormalization(parameters_shape=[d_model])
        self.dropout1 = nn.Dropout(p=drop_prob)
        self.ffn = PositionwiseFeedForward(d_model=d_model, hidden=ffn_hidden, drop_prob=drop_prob)
        self.norm2 = LayerNormalization(parameters_shape= [d_model])
        self.dropout2 = nn.Dropout(p=drop_prob)
        
    def forward(self, x, self_attention_mask):
        residual_x = x.clone()
        x = self.attention(x, mask=self_attention_mask)
        x = self.dropout1(x)
        x = self.norm1(x + residual_x)
        residual_x = x.clone()
        x = self.ffn (x)
        x = self.dropout2(x)
        x = self.norm2(x + residual_x)
        return x

# %%
class SequentialEncoder(nn.Sequential):
    def forward(self, *inputs):
        x, self_attention_mask = inputs
        for module in self._modules.values():
            x = module(x, self_attention_mask)
        return x

# %%
class Encoder(nn.Module) :
    def __init__(self, 
                 d_model, 
                 ffn_hidden, 
                 num_heads, 
                 drop_prob, 
                 num_layers, 
                 max_sequence_length, 
                 language_to_index,
                 START_TOKEN, 
                 END_TOKEN,
                 PADDING_TOKEN) :
        super().__init__()
        self.sentence_embedding = SentenceEmbedding(max_sequence_length, d_model, language_to_index, START_TOKEN, END_TOKEN, PADDING_TOKEN)
        self.layers = SequentialEncoder(*[EncoderLayer(d_model, ffn_hidden, num_heads, drop_prob)
                                          for _ in range (num_layers)])
    
    def forward(self, x, self_attention_mask, start_token, end_token):
        x = self.sentence_embedding(x, start_token, end_token)
        x = self.layers(x, self_attention_mask)
        return x

# %%
class MultiHeadCrossAttention(nn.Module):
    def __init__(self, d_model, num_heads) :
        super().__init__()
        self.d_model = d_model
        self.num_heads = num_heads
        self.head_dim = d_model // num_heads
        self.kv_layer = nn.Linear(d_model, 2 * d_model)
        self.q_layer = nn.Linear (d_model, d_model)
        self.linear_layer = nn.Linear(d_model, d_model)
    
    def forward(self, x, y, mask):
        batch_size, sequence_length, d_model = x.size() # in practice, this is the same for both languages...
        kv = self.kv_layer(x)
        q = self.q_layer(y)
        kv = kv.reshape(batch_size, sequence_length, self.num_heads, 2 * self.head_dim)
        q = q.reshape(batch_size, sequence_length, self.num_heads, self.head_dim)
        kv = kv.permute(0, 2, 1, 3)
        q = q.permute(0, 2, 1, 3)
        k, v = kv.chunk(2, dim=-1)
        values, attention = scaled_dot_product(q, k, v, mask) # We don't need the mask for cross attention, removing in outer function!
        values = values.permute(0, 2, 1, 3).reshape(batch_size, sequence_length, d_model)
        out = self.linear_layer(values)
        return out

# %%
class DecoderLayer(nn.Module):
    def __init__(self, d_model, ffn_hidden, num_heads, drop_prob):
        super(DecoderLayer, self).__init__()
        self.self_attention = MultiHeadAttention(d_model=d_model, num_heads=num_heads)
        self.layer_norm1 = LayerNormalization(parameters_shape=[d_model])
        self.dropout1 = nn.Dropout(p=drop_prob)
        
        self.encoder_decoder_attention = MultiHeadCrossAttention(d_model=d_model, num_heads=num_heads)
        self.layer_norm2 = LayerNormalization(parameters_shape=[d_model])
        self.dropout2 = nn.Dropout(p=drop_prob)
        
        self.ffn = PositionwiseFeedForward(d_model=d_model, hidden=ffn_hidden, drop_prob=drop_prob)
        self.layer_norm3 = LayerNormalization(parameters_shape=[d_model])
        self.dropout3 = nn.Dropout(p=drop_prob)
    
    def forward(self, x, y, self_attention_mask, cross_attention_mask):
        _y = y.clone()
        y = self.self_attention(y, mask=self_attention_mask)
        y = self.dropout1(y)
        y = self.layer_norm1(y + _y)
        
        _y = y.clone()
        y = self.encoder_decoder_attention(x, y, mask=cross_attention_mask)
        y = self.dropout2(y)
        y = self.layer_norm2(y + _y)
        
        _y = y.clone()
        y = self.ffn(y)
        y = self.dropout3(y)
        y = self.layer_norm3(y + _y)
        return y

# %%
class SequentialDecoder(nn.Sequential):
    def forward (self, *inputs):
        x, y, self_attention_mask, cross_attention_mask = inputs
        for module in self._modules.values():
            y = module(x, y, self_attention_mask, cross_attention_mask)
        return y

# %%
class Decoder(nn.Module): 
    def __init__(self, 
                 d_model, 
                 ffn_hidden,
                 num_heads,
                 drop_prob,
                 num_layers,
                 max_sequence_length, 
                 language_to_index,
                 START_TOKEN, 
                 END_TOKEN, 
                 PADDING_TOKEN):
        super().__init__()
        self.sentence_embedding = SentenceEmbedding(max_sequence_length, d_model, language_to_index, START_TOKEN, END_TOKEN, PADDING_TOKEN)
        self.layers = SequentialDecoder(*[DecoderLayer(d_model, ffn_hidden, num_heads, drop_prob) 
                                          for _ in range(num_layers)])
    
    def forward(self, x, y, self_attention_mask, cross_attention_mask, start_token, end_token) :
        y = self.sentence_embedding (y, start_token, end_token)
        y = self.layers(x, y, self_attention_mask, cross_attention_mask)
        return y

# %%
class Transformer(nn.Module): 
    def __init__(self, 
                 d_model, 
                 ffn_hidden,
                 num_heads,
                 drop_prob,
                 num_layers,
                 max_sequence_length, 
                 hn_vocab_size,
                 english_to_index, 
                 hindi_to_index,
                 START_TOKEN, 
                 END_TOKEN, 
                 PADDING_TOKEN):

        super().__init__()
        self.encoder = Encoder(d_model, ffn_hidden, num_heads, drop_prob, num_layers, max_sequence_length, english_to_index, START_TOKEN, END_TOKEN, PADDING_TOKEN)
        self.decoder = Decoder(d_model, ffn_hidden, num_heads, drop_prob, num_layers, max_sequence_length, hindi_to_index, START_TOKEN, END_TOKEN, PADDING_TOKEN)
        self.linear = nn.Linear(d_model, hn_vocab_size)
        self.device = device
        
    def forward(self,
                x,
                y, 
                encoder_self_attention_mask=None, 
                decoder_self_attention_mask=None, 
                decoder_cross_attention_mask=None, 
                enc_start_token=False, 
                enc_end_token=False,
                dec_start_token=False, 
                dec_end_token=False):
    
        # Pass encoder outputs and decoder inputs to the decoder
        x = self.encoder(x, encoder_self_attention_mask, start_token=enc_start_token, end_token=enc_end_token)
        out = self.decoder(x, y, decoder_self_attention_mask, decoder_cross_attention_mask, start_token=dec_start_token, end_token=dec_end_token)
        out = self.linear(out) # Generate final predictions
        return out

# %% [markdown]
# ## Defining Model

# %%
# Define parameters
d_model = 256
batch_size = 50
ffn_hidden = 2048
num_heads = 8
drop_prob = 0.1
num_layers = 5
max_sequence_length = 150 #I've checked it in exploratary analysis-> 90 is ideal

# %% [markdown]
# ## Preparing Data

# %% [markdown]
# ### Read hindi file clean a bit and write it down again.

# %%
base_path = '/Users/siddharthchaudhary/Documents/git_repos/AI-Models/Transformer_from_scratch/Dataset/'

# %%
hindi_english_data_path =  base_path + 'Dataset_English_Hindi.csv'
train_en_file = base_path + 'vocab_and_training_files/train_en.txt'
train_hn_file = base_path + 'vocab_and_training_files/train_hn.txt'
english_vocab_file = base_path + 'vocab_and_training_files/english_vocab.txt'
hindi_vocab_file = base_path + 'vocab_and_training_files/hindi_vocab.txt'

# %%
lines = (pd. read_csv(hindi_english_data_path).rename (columns = {'English': 'english', 'Hindi': 'hindi'}))
# lines = lines [:1000000]
lines = lines[:10000]
lines.head()
# Out:
#   english    hindi
# 0   Help!    बचाओ!
# 1   Jump.    उछलो.
# 2   Jump.    कूदो.
# 3   Jump.   छलांग.
# 4  Hello!  नमस्ते।

# %%
lines.tail()
# Out:
#                                                 english  \
# 9995  That involves vast and revolutionary changes i...
# 9996                              When women is on top.
# 9997  A cricket match can be won by a team by making...
# 9998  Earth outer surface is divided into several ri...
# 9999  Gumbhan: Aukar Joshi's Indian language word-pr...
#
#                                                   hindi
# 9995  इसके लिए हमारे राजनैतिक और सामाजिक ढांचे में व...
# 9996                                    जब महिला उपर हो
# 9997  क्रिकेट में खेल को ज्यादा रन बना कर भी जीता जा...
# 9998  पृथ्वी की बाहरी सतह (outer surface) कई कठोर खं...
# 9999  गमभन : ओंकार जोशी का भारतीय भाषा शब्द-संसाधक (...

# %%
missing_data = lines.isnull().sum().to_frame().rename(columns={0:"Total No. of Missing Values"})
missing_data["% of Missing Values"] = round((missing_data["Total No. of Missing Values"]/len(lines))*100,2)

# %%
round(lines.describe().T,2)
# Out:
#          count unique         top freq
# english  10000   9702  (Laughter)   39
# hindi     9982   9626      (हँसी)   15

# %%
lines.drop_duplicates(inplace = True)

# %%
lines = lines.dropna(subset=["hindi", "english"])
lines.head()
# Out:
#   english    hindi
# 0   Help!    बचाओ!
# 1   Jump.    उछलो.
# 2   Jump.    कूदो.
# 3   Jump.   छलांग.
# 4  Hello!  नमस्ते।

# %%
lines.shape
# Out:
# (9916, 2)

# %%
# Lowercase all characters
lines['english'] = lines['english'].str.lower()

# %%
# Remove HTML
def remove_html_tags(text):
    # Corrected pattern: Only allows alphanumeric characters and spaces
    pattern = r'[^a-zA-Z0-9\s]'
    text = re.sub(pattern, '', text)
    return text


lines['english'] = lines['english'].apply(remove_html_tags)

# %%
# remove URLS
def remove_url(text):
    # Correct regex to match URLs
    pattern = re.compile(r'https?://\S+|www\.\S+')
    return pattern.sub('', text)
    
lines['english'] = lines['english'].apply(remove_url)
lines['hindi'] = lines['hindi'].apply(remove_url)
lines.head()
# Out:
#   english    hindi
# 0    help    बचाओ!
# 1    jump    उछलो.
# 2    jump    कूदो.
# 3    jump   छलांग.
# 4   hello  नमस्ते।

# %%
chat_words = {
    "AFAIK": "As Far As I Know",
    "AFK": "Away From Keyboard",
    "ASAP": "As Soon As Possible",
    "ATK": "At The Keyboard",
    "ATM": "At The Moment",
    "А3": "Anytime, Anywhere, Anyplace",
    "BAK": "Back At Keyboard",
    "BBL": "Be Back Later",
    "BBS": "Be Back Soon",
    "BFN": "Bye For Now",
    "B4N": "Bye For Now",
    "BRB": "Be Right Back",
    "BRT": "Be Right There",
    "BTW": "By The Way",
    "B4": "Before",
    "CU": "See You",
    "CUL8R": "See You Later",
    "CYA": "See You",
    "FAO": "Frequently Asked Questions",
    "FC": "Fingers Crossed",
    "FWIW": "For What It's Worth",
    "FYI": "For Your Information",
    "GAL": "Get A Life",
    "GG": "Good Game",
    "GN": "Good Night",
    "GMTA": "Great Minds Think Alike",
    "GR8": "Great!",
    "G9": "Genius",
    "IC": "I See",
    "ICQ": "I Seek you (also a chat program)",
    "ILU": "I Love You",
    "IMHO": "In My Honest/Humble Opinion",
    "IMO": "In My Opinion",
    "IOW": "In Other Words",
    "IRL": "In Real Life",
    "KISS": "Keep It Simple, Stupid",
    "LDR": "Long Distance Relationship",
    "LMAO": "Laugh My A.. Off",
    "LOL": "Laughing Out Loud",
    "LTNS": "Long Time No See",
    "L8R": "Later",
    "MTE": "My Thoughts Exactly",
    "NRN": "No Reply Necessary",
    "OIC":"Oh I See",
    "PITA": "Pain In The A..",
    "PRT": "Party",
    "PRW": "Parents Are Watching",
    "QPSA": "Que Pasa?",
    "ROFL": "Rolling On The Floor Laughing",
    "ROFLOL": "Rolling On The Floor Laughing Out Loud",
    "ROTFLMAO": "Rolling On The Floor Laughing My A.. Off",
    "SK8": "Skate",
    "STATS": "Your sex and age",
    "ASL": "Age, Sex, Location",
    "THX": "Thank You",
    "TTFN" : "Ta-Ta For Now!",
    "TTYL": "Talk To You Later",
    "U": "You",
    "U2": "You Too",
    "U4E": "Yours For Ever",
    "WB": "Welcome Back",
    "WUF": "Where Are You From?",
    "TFW": "That feeling when",
    "MFW": "My face when",
    "MRW": "My reaction when",
    "IFYP": "I feel your pain",
    "LOL": "Laughing out loud",
    "TNTL": "Trying not to laugh",
    "JK": "Just kidding",
    "IDC": "I don't care",
    "ILY": "I love you",
    "IMU": "I miss you",
    "ADIH": "Another day in hell",
    "IDC": "I don't care",
    "ZZZ": "Sleeping, bored, tired",
    "WYWH": "Wish you were here",
    "TIME": "Tears in my eyes",
    "BAE": "Before anyone else",
    "FIMH": "Forever in my heart",
    "BSAAW": "Big smile and a wink",
    "BWL": "Bursting with laughter",
    "LMAO": "Laughing my a** off",
    "BFF": "Best friends forever",
    "CSL": "Can't stop laughing"
}

# %%
def chat_conversion(text):
    new_text=[]
    for w in text.split():
        if w.upper() in chat_words:
            new_text.append(chat_words[w.upper()])
        else:
            new_text.append(w)
    return " ".join(new_text)

lines['english'] = lines['english'].apply(chat_conversion)

# %%
lines.head()
# Out:
#   english    hindi
# 0    help    बचाओ!
# 1    jump    उछलो.
# 2    jump    कूदो.
# 3    jump   छलांग.
# 4   hello  नमस्ते।

# %%
def remove_emoji(text):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F" 
                               u"\U0001F300-\U0001F5FF"
                               u"\U0001F680-\U0001F6FF" 
                               u"\U0001F1E0-\U0001F1FF"
                               u"\U00002702-\U000027B0" 
                               u"\U000024C2-\U0001F251"
                               "]+", flags=re.UNICODE)
    
    return emoji_pattern.sub(r'', text)

# %%
lines.head()
# Out:
#   english    hindi
# 0    help    बचाओ!
# 1    jump    उछलो.
# 2    jump    कूदो.
# 3    jump   छलांग.
# 4   hello  नमस्ते।

# %%
lines.shape
# Out:
# (9916, 2)

# %%
lines['english'] = lines['english'].apply(remove_emoji)
lines['hindi'] = lines['hindi'].apply(remove_emoji)

# %%
# Contraction:- y're → you are 
def expand_contractions (text):
    expanded_text = contractions.fix(text)
    return expanded_text
    
lines['english'] = lines['english'].apply(expand_contractions)
lines.head()
# Out:
#   english    hindi
# 0    help    बचाओ!
# 1    jump    उछलो.
# 2    jump    कूदो.
# 3    jump   छलांग.
# 4   hello  नमस्ते।

# %%
# Remove Non-Hindi and Alphanumeric characters
def preprocess_text(text, language='english'):
    if not isinstance(text, str):
        return text  
    if language == 'english':
        pattern = re. compile(r'[^a-zA-Z0-9\s]')
        return pattern.sub(r'', text)
    elif language == 'hindi':
        pattern = re. compile(r'[^\u0900-\u097F\s]')
        return pattern. sub(r'', text)
    else:
        raise ValueError ("Unsupported Language, Supported languages are 'english' and 'hindi'")

lines['english'] = lines['english'].apply(lambda x: preprocess_text(x, language='english'))
lines['hindi'] = lines['hindi'].apply(lambda x: preprocess_text(x, language='hindi'))

# %%
# Get the number of words count in each sentence for hindi and english
lines['length_eng']=lines['english'].apply(lambda x: len(x.split(" ")) )
lines['length_hin']=lines['hindi'].apply(lambda x: len(x.split(" ")))

# %%
# Function to check if sentence containg Hindi alphabets in the English column
def remove_hindi_alphabets (text) :
    return re.sub("[\u0900-\u097F]", "", text)
    
# Apply the function to the English column
lines['english'] = lines['english'].apply(remove_hindi_alphabets)
lines = lines.dropna(subset= ["hindi", "english"])
lines
# Out:
#                                                 english  \
# 0                                                  help
# 1                                                  jump
# 2                                                  jump
# 3                                                  jump
# 4                                                 hello
# ...                                                 ...
# 9995  that involves vast and revolutionary changes i...
# 9996                               when women is on top
# 9997  a cricket match can be won by a team by making...
# 9998  earth outer surface is divided into several ri...
# 9999  gumbhan aukar joshis indian language wordproce...
#
#                                                   hindi  length_eng  \
# 0                                                  बचाओ           1
# 1                                                  उछलो           1
# 2                                                  कूदो           1
# 3                                                 छलांग           1
# 4                                               नमस्ते।           1
# ...                                                 ...         ...
# 9995  इसके लिए हमारे राजनैतिक और सामाजिक ढांचे में व...          31
# 9996                                    जब महिला उपर हो           5
# 9997  क्रिकेट में खेल को ज्यादा रन बना कर भी जीता जा...          31
# 9998  पृथ्वी की बाहरी सतह   कई कठोर खंडों या विवर्तन...         102
# 9999        गमभन  ओंकार जोशी का भारतीय भाषा शब्दसंसाधक            6
#
#       length_hin
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 9995          54
# 9996           4
# 9997          25
# 9998          50
# 9999           9
#
# [9916 rows x 4 columns]

# %%
# Remove extra spaces
lines['english']=lines['english'].apply(lambda x: x.strip())
lines['hindi']=lines['hindi'].apply(lambda x: x.strip ())

# %%
lines[lines['length_eng'] > 150].shape
# Out:
# (3, 4)

# %%
lines[lines['length_hin'] > 150].shape
# Out:
# (8, 4)

# %%
lines = lines[lines['length_eng']<=150]
lines = lines[lines['length_hin']<=150]

# %%
lines.shape
# Out:
# (9907, 4)

# %%
print("maximum length of Hindi Sentence ", max(lines ['length_hin'])) 
print("maximum length of English Sentence ", max (lines ['length_eng']))
# Out:
# maximum length of Hindi Sentence  149
# maximum length of English Sentence  150

# %%
lines.head()
# Out:
#   english    hindi  length_eng  length_hin
# 0    help     बचाओ           1           1
# 1    jump     उछलो           1           1
# 2    jump     कूदो           1           1
# 3    jump    छलांग           1           1
# 4   hello  नमस्ते।           1           1

# %%
hindi_sentences = lines['hindi'].values.tolist()
english_sentences = lines['english'].values.tolist()

# %%
### Get English and Hindi Vocabulary
all_eng_words = set()
for eng in lines['english']:
    all_eng_words.update(eng.split())

all_hindi_words = set ()
for hin in lines['hindi']:
    all_hindi_words.update(hin.split())

# %%
hindi_vocab = list(all_hindi_words)
print(len(hindi_vocab))
english_vocab = list(all_eng_words)
print(len(english_vocab))
# Out:
# 18298
# 15841

# %% [markdown]
# ### Now Writing the hindi, english text and vocab created in above 3 cells

# %%
file = open(train_en_file,'w')
for sentence in english_sentences:
    file.write(sentence+"\n")
file.close()

# %%
file = open(train_hn_file,'w')
for sentence in hindi_sentences:
    file.write(sentence+"\n")
file.close()

# %%
file = open(english_vocab_file, 'w')
for word in english_vocab: 
    file.write(word+"\n")
file.close()

# %%
file = open(hindi_vocab_file, 'w')
for word in hindi_vocab:
    file.write (word+"\n")
file.close()

# %%
# Delete dataframes to release memory
del lines 
del all_eng_words 
del all_hindi_words 
del hindi_sentences 
del english_sentences 
del hindi_vocab 
del english_vocab
# Run garbage collector
gc.collect()
# Out:
# 0

# %% [markdown]
# ### Reading the hindi, english text and vocab

# %%
with open(train_en_file, 'r') as file:
    english_sentences = file.readlines()
english_sentences = [sentence.rstrip('\n') for sentence in english_sentences]
english_sentences[:10]
# Out:
# ['help',
#  'jump',
#  'jump',
#  'jump',
#  'hello',
#  'hello',
#  'cheers',
#  'cheers',
#  'got it',
#  'i am ok']

# %%
with open(train_hn_file, 'r') as file:
    hindi_sentences = file.readlines()
hindi_sentences = [sentence.rstrip('\n') for sentence in hindi_sentences]
hindi_sentences[: 10]
# Out:
# ['बचाओ',
#  'उछलो',
#  'कूदो',
#  'छलांग',
#  'नमस्ते।',
#  'नमस्कार।',
#  'वाहवाह',
#  'चियर्स',
#  'समझे कि नहीं',
#  'मैं ठीक हूँ।']

# %%
with open(hindi_vocab_file, 'r') as file:
    hindi_vocab = file.readlines ()
hindi_vocab = [word.rstrip('\n') for word in hindi_vocab]
print(len(hindi_vocab) )
print(hindi_vocab)
# Out:
# 18298
# ['हवाईजहाज़', 'पुस्तकें', 'क्रिसेंट', 'शोधसमूह', 'अभिन्न', 'कर्णकूट', 'गुजरी', 'हैंसेल', 'प्रत्याशी', 'बल्लेबाज', 'वेबवार्ता', 'इच्छामती', 'रूपाकार', 'साम्यवादी', 'हाथः', '१६००', 'चोला', 'नागपुर', 'युद्धग्रस्त', 'साधारणत', 'खिताब', 'आर्गनिक', 'मेजबान', 'ज़ारी', 'गिरनी', 'रनो', 'शोले', 'समाविष्ट', 'भागवती', 'पेशकश', 'अवलोकन', 'एपीजे', 'आज़ादी', 'इज़्जत', 'स्थगन', 'गुणों', 'रेसियल', 'अंधेर', 'चमत्कार', 'कटाई', 'टोरी', 'ग़लतफ़ैमी', 'सलहमशविरा', 'सुलझाने', 'जाद', 'कुरआन', 'अहमियत', 'डेनिश', 'पंत', 'टिहरी', 'प्रजातियां', 'कुडई', 'हुमायुं', 'एकदूसरे', 'कॉण्ट्रैक्ट', 'बताया।', 'पहाड़ी', 'अमोनिया', 'ञुनेरल्', 'क्रमांक', 'प्रांतो', 'चर्चाओं', 'संवेदनशील', 'भार', 'सट्', 'बनेगा', 'पत्तनों', 'रसायन', 'भुलने', 'रह', 'अखबारों', 'एमी', 'बुनें', 'धुए', 'बधाईयाँ।', '६३२', 'अधिरथ', 'अन्योन्य', 'आन्दोलन', 'दूतावास', 'रक्षात्मक', 'आयोजित', 'छोड़ूँ', 'बहुदेववाद', 'गुच्छे', 'नाभा', 'नौकरियां', 'विकृत', 'चोगा', 'सॉफ्टवेर', 'ललीतपुर', 'वैश्विक', 'नववर्ष', 'गफलत', 'उसकाउसकी', 'चाहिएफर्श', 'नवीकरणीय', 'नीहार', '६७वीं', 'निकोबार', 'करीगर', 'खोखर', 'लीथियमबहुलक', 'अरण्यकपर्व', 'आतंकवादी', 'सैनिक', 'नाचना', 'योग़्यता', 'कोसों', 'केंचुआ', 'सुपरमार्केट', 'क्रियान्वयन', 'व्यग्रता', 'ऋऋपिछले', 'संरक्षण', 'उठा।', 'सनकी', 'अध्यक्षसभापति', 'अग्रेषित', 'बर्लिन', 'परिणामों', 'घुअर्डिअन्', 'राजग', 'थूक', 'गोइथे', 'उत्पन्न', 'विमोचन', 'पत्रिका', 'बोलिए।', 'चारा', 'रवीन्द्रनाथआधुनिक', 'विचलित', 'माऋग', 'सत्य', 'एकत्र', 'ओलती', 'कीटों', 'भरी।', 'अनुच्छेद', 'अक्षत', 'दार्शनिक', 'फैलने', 'एक्सचेंज', 'अनोखी', 'उदारवादी', 'बड़', 'सुहृद', 'प्रतिकारक', 'काक़्स', 'सर्वव्यापी', 'अवैध', 'वाष्पशील', 'महमूब', 'लल', 'अतंराल', 'सौदे', 'रति', 'उदात्त', 'युवकयुवतियां', 'दीर्घकाल', 'कुआललंपुर', '२००१।', 'ब्रौंज', 'दुनिया।', 'गुस्से', 'प्रयोजन', 'कुशलता', 'प्रवाहों', 'महेंद्रवाड़ी', 'सीखी', 'धर्मगुरु', 'सारा', 'हैइसमें', 'करवाता', 'फौजों', 'श्रेणीसंस्कृत', 'कफ', 'हेज', 'आदी', 'विशुद्ध', 'हेरफेर', 'देरी', 'रजी', 'मकसद', 'मुर्गे', 'भाग।', 'सहयोग', 'क़रीबनक़रीबन', 'फोटोग्राफ़रों', 'शॉ', 'खामियों', 'हड्डी', 'निकट', 'मोबाईल', 'अनहोनी', 'तराशे', 'ऋग्वेद', 'चूर्णी', 'पारियां', 'रेड', 'बर्बाद', 'निराकार', 'विपक्षी', 'रिलयंस', 'गठबंधन', 'उन्मूलनको', 'नरेश', 'लेखक', 'सेवियों', 'साँयः', 'शिक्षकसंस्करण', 'बहकर', 'जये', 'मतानुसार', 'मेरी', 'जातिगत', 'अचऋऊण्श्छ्ष्छी', 'यज्ञानुष्ठान', 'जालीदार', 'दूरदर्शन', 'गा', 'घंटा', 'प्रौद्योगिकीय', 'वॉशिंग', 'होयसलेश्वर', 'बागबाग', 'खयाल', 'बुखार', 'बल', 'वासुदेव', 'मानवशरीर', 'उपयोगिता', 'आये', 'वतन।', 'वक्ताओं', 'अबुल', 'पीउ', 'जीवनशैली', 'हेस्टिग़्ज', 'तिबत', 'दीनएइलाही', 'गले', 'कंबल', 'वाइसराय', 'वाष्पीकरण', 'हतोत्साहित', 'श्रेय', 'चालीस', 'रामास्वामी', 'मंत्र', 'मिस्र', 'कारी', 'दूंगा', 'वास्तुशिल्प', 'मध्यस्थ', 'चोटी', 'लागु', 'परिवर्णी', 'लियोनार्डो', 'सामरिक', 'संक्षेप', 'मामलं', 'देखिये', 'किसी', 'समाजशास्त्रीय', 'त्योहार', '१०००', 'खनन', 'संस्थापित', 'बैठो।', 'बनते', 'वह', 'बढ़ावा', 'कर्मकाण्ड', 'लेट', 'क्षति', 'सीसा', 'देशबन्धु', 'अलीरजी', 'गणतंत्र', 'पड़ीं।', 'रिओ', 'हंसी', 'तोझुबूर', 'जलाकर', 'हिंसात्मक', 'हिंदुसऋऊण्श्छ्ष्तान', 'व्यापक', 'पंहुचा', 'हत्यारों', 'चेचेन्या', 'मकबरे', 'गोलमेज', 'मस्जिद', 'टटोलें', 'दशद्वार', 'सफाई', 'मौजूदगी', 'मलिन', 'कुंवर', 'निहित', 'कद्र', 'कलाकृति', 'विधिमान्य', 'त्त्व', 'तूफान', 'धान', 'वर्ण', 'परदे', 'पुनरावृत्ति', 'गुणसूत्र', 'रेट्रोफिट', 'ज़िंदा', 'लोगो', 'निपटारे', 'किराये', 'रुपरेखा', 'संस्किऋत', 'डॉक्टर', 'लगनी', 'थीं', 'दोतिहाई', 'लगता', 'न्यायपालिका', 'सीखते', 'कंदबों', 'टैक़्स', 'पैटर्न', 'वाणी', 'थायह', 'सन्देश', 'मार्गदर्शनों', 'लग', 'सुपरमैन', 'भारदारो', 'औरभीऔर', 'शिरकत', 'जनसाधारण', 'गौरव', 'तोहोलू', 'सिखाकर', 'चित्रकार', 'संप्रदायवाद', 'विकिरणों', 'मचाओ।', 'दुरूस्त', '५३७', 'सुप्रीमो', 'सिस्टेम्स', 'नेतासभी', 'चौदय्या', 'बना', 'लिखीं', 'ऊब', 'दलभाजपा', 'लीं', 'छोड़ो।', 'लीफलेट्स', 'को', 'सल्ल', 'जोडऋ', 'हुँ', 'गंभीरता', 'सीडियों', 'महा', 'सामजिक', 'नदियाँ', 'अग', 'कपूर', 'प्रतिक्रिया', 'सम्राट', 'डपयॊग', 'उपक्रम', 'बलजीत', 'देहव्यापारी', 'श्रेणीहिन्दू', 'परंपरा', 'प्रतिबंधित', 'अवधिहृ', 'यह्', 'आजाओ।', 'कनाडियन', 'कोई', '२३', 'जोसेफ', 'टंगस्टन', 'पहुऋचाता', 'मिथकों', 'कृतित्रम', 'सहचारिता', 'भट्टी ...

# %%
with open (english_vocab_file, 'r') as file:
    english_vocab= file.readlines()
english_vocab = [word.rstrip('\n') for word in english_vocab]
print(len(english_vocab))
print(english_vocab)
# Out:
# 15841
# ['spirituality', 'tell', '1350', 'exyernal', 'office', 'field', 'disasters', 'hindienglish', 'koneri', 'subtropical', 'estranged', 'loksabha', 'cloister', 'krupacharya', 'san', 'wasted', 'ellora', 'wang', 'antenatal', 'receptions', 'housing', 'marking', 'financial', 'buffaloes', 'storm', 'processes', 'far', 'moves', 'crack', 'companion', 'vivekanand12th', 'chap', 'nandikeshwar', 'alert', 'tours', 'returned', 'collectively', 'abusers', 'mulayam', 'thrissur', 'interchangeably', 'obstructing', 'chickens', 'site', 'intake', 'pandavas', 'parvati', 'india', 'bhayander', 'snowball', 'factual', 'marvel', 'writerdevelopment', 'torn', 'lightful', '3member', 'supposing', 'prevent', 'polished', 'catch', 'uninspiring', '8th', 'rjd', 'antihindu', 'paidup', 'nonreligious', 'supermarkets', 'cicada', 'toothbrush', 'treats', 'frequencies', 'motheaten', '20000', 'conciliation', 'expiation', 'uncertain', 'bald', 'rudracharya', 'ajit', 'skeletons', 'subba', '2004', 'extenuating', 'sursagar', 'bharata', 'always', 'fifteen', '2003', 'collection', 'todaybritish', 'disloyal', 'hoped', 'statue', 'pawns', 'adult', 'effects', 'water', 'tongues', 'walking', 'liming', 'vimanas', 'routes', 'pigeon', 'complete', 'tulaja', 'observation', 'wwwtmjorg', 'pests', 'worship', 'impossible', 'lifethis', 'muslin', 'embarrassed', 'engines', 'adi', 'sophistry', 'mahendra', 'trade', 'procedural', 'deshbandhu', 'reshuffle', 'classified', 'doordarshan', 'robust', 'idealistic', 'crippled', 'extant', 'initiated', 'statistical', 'japanese', 'registered', 'monotheist', 'basins', 'govindharajulu', 'attainments', 'slavery', 'institutions', 'catapulted', 'prithvi', 'intimacy', 'withdraw', 'toughness', 'proven', 'suggests', 'cameroon', 'boli', 'intensely', 'assault', 'danceroom', 'dar', 'pulses', '60', '422crore', 'curved', 'dislocation', 'seicho', 'sittings', 'congress', 'invariably', 'ladhakh', 'arose', 'sures', 'lobar', 'protocol', 'knit', 'discussions', 'congested', 'weird', 'launching', 'reducing', 'facto', 'assistant', 'dynamics', 'swift', 'swang', 'hajarat', 'punjab', 'obligation', 'shifting', 'grey', 'evaporates', 'industrialization', 'outlook', 'metabolic', 'immunities', 'lightknowledge', 'islamic', 'optimistic', 'investment', 'acquired', 'ramakrishna', 'prohibition', 'delaware', 'mugal', 'chingleput', '29', 'joust', 'efficiency', 'motprola', 'terriorist', 'items', 'yashodhara', 'shuangeri', 'marks', 'rajagopal', 'kinchinjunga', 'adjournment', 'simplification', 'subordinate', 'effortlessly', 'nataraja', 'nevada', 'shot', 'prostration', 'parable', 'abcl', 'intermingled', 'passing', 'khalifas', 'atom', 'basrelief', 'themes', 'shankar', 'drudgery', 'purushottam', 'guerrilla', 'nahar', 'dreamentranced', 'gross', 'experimental', 'bali', '195556', 'beleaguered', 'fitzgerald', 'uptodate', 'that', 'demanding', 'opponent', 'rocks', 'proportionate', 'tremendous', 'untill', 'motor', 'virus', 'mewar', 'colossal', 'bombing', 'archaic', 'sinkhandhar', 'street', 'competition', 'violent', 'korey', 'wealthy', 'rumor', 'communications', 'isd', '106', 'diseaseaccording', 'dissatisfied', 'curve', 'ayurveda', 'arya', 'lyall', 'rhetoric', 'appeals', 'proove', 'quacks', 'closed', 'souvenirs', 'hooghly', 'equipments', 'baap', 'glare', 'om', 'caveats', 'parsouli', 'vital', 'aback', 'underside', 'webpages', 'metallic', 'prabhupad', 'lashes', 'relies', 'compassion', 'removed', 'confusing', 'disabilities', 'statutory', '25980', 'vary', 'societiesand', 'ache', 'window', 'camps', '310', 'ponds', 'beamed', 'unwithered', 'proposed', 'grain', 'contemporaries', 'presenting', 'parliament', 'fateh', 'vases', 'other', 'temitiye', 'pharmaceutical', 'o3', 'urn', 'photos', 'ferrotungsten', 'legislate', 'treaty', 'selfrespect', 'communist', 'souls', 'varsovato', 'acquire', '110', '3300', 'kulti', 'profusions', 'costly', 'animalbased', 'purul', 'reversal', 'estimates', 'ambition', 'shri', 'similarly', 'negligible', 'sesherkavita', 'verma', 'digged', 'textile', 'walls', 'catalog', 'morefor', 'ghaughat', 'occured', ...

# %%
START_TOKEN = '<START>'
PADDING_TOKEN = '<PADDING>'
END_TOKEN = '<END>'

# %%
hindi_vocab.insert(0, START_TOKEN)
hindi_vocab.append(PADDING_TOKEN)
hindi_vocab.append(END_TOKEN)
print(hindi_vocab)
# Out:
# ['<START>', 'हवाईजहाज़', 'पुस्तकें', 'क्रिसेंट', 'शोधसमूह', 'अभिन्न', 'कर्णकूट', 'गुजरी', 'हैंसेल', 'प्रत्याशी', 'बल्लेबाज', 'वेबवार्ता', 'इच्छामती', 'रूपाकार', 'साम्यवादी', 'हाथः', '१६००', 'चोला', 'नागपुर', 'युद्धग्रस्त', 'साधारणत', 'खिताब', 'आर्गनिक', 'मेजबान', 'ज़ारी', 'गिरनी', 'रनो', 'शोले', 'समाविष्ट', 'भागवती', 'पेशकश', 'अवलोकन', 'एपीजे', 'आज़ादी', 'इज़्जत', 'स्थगन', 'गुणों', 'रेसियल', 'अंधेर', 'चमत्कार', 'कटाई', 'टोरी', 'ग़लतफ़ैमी', 'सलहमशविरा', 'सुलझाने', 'जाद', 'कुरआन', 'अहमियत', 'डेनिश', 'पंत', 'टिहरी', 'प्रजातियां', 'कुडई', 'हुमायुं', 'एकदूसरे', 'कॉण्ट्रैक्ट', 'बताया।', 'पहाड़ी', 'अमोनिया', 'ञुनेरल्', 'क्रमांक', 'प्रांतो', 'चर्चाओं', 'संवेदनशील', 'भार', 'सट्', 'बनेगा', 'पत्तनों', 'रसायन', 'भुलने', 'रह', 'अखबारों', 'एमी', 'बुनें', 'धुए', 'बधाईयाँ।', '६३२', 'अधिरथ', 'अन्योन्य', 'आन्दोलन', 'दूतावास', 'रक्षात्मक', 'आयोजित', 'छोड़ूँ', 'बहुदेववाद', 'गुच्छे', 'नाभा', 'नौकरियां', 'विकृत', 'चोगा', 'सॉफ्टवेर', 'ललीतपुर', 'वैश्विक', 'नववर्ष', 'गफलत', 'उसकाउसकी', 'चाहिएफर्श', 'नवीकरणीय', 'नीहार', '६७वीं', 'निकोबार', 'करीगर', 'खोखर', 'लीथियमबहुलक', 'अरण्यकपर्व', 'आतंकवादी', 'सैनिक', 'नाचना', 'योग़्यता', 'कोसों', 'केंचुआ', 'सुपरमार्केट', 'क्रियान्वयन', 'व्यग्रता', 'ऋऋपिछले', 'संरक्षण', 'उठा।', 'सनकी', 'अध्यक्षसभापति', 'अग्रेषित', 'बर्लिन', 'परिणामों', 'घुअर्डिअन्', 'राजग', 'थूक', 'गोइथे', 'उत्पन्न', 'विमोचन', 'पत्रिका', 'बोलिए।', 'चारा', 'रवीन्द्रनाथआधुनिक', 'विचलित', 'माऋग', 'सत्य', 'एकत्र', 'ओलती', 'कीटों', 'भरी।', 'अनुच्छेद', 'अक्षत', 'दार्शनिक', 'फैलने', 'एक्सचेंज', 'अनोखी', 'उदारवादी', 'बड़', 'सुहृद', 'प्रतिकारक', 'काक़्स', 'सर्वव्यापी', 'अवैध', 'वाष्पशील', 'महमूब', 'लल', 'अतंराल', 'सौदे', 'रति', 'उदात्त', 'युवकयुवतियां', 'दीर्घकाल', 'कुआललंपुर', '२००१।', 'ब्रौंज', 'दुनिया।', 'गुस्से', 'प्रयोजन', 'कुशलता', 'प्रवाहों', 'महेंद्रवाड़ी', 'सीखी', 'धर्मगुरु', 'सारा', 'हैइसमें', 'करवाता', 'फौजों', 'श्रेणीसंस्कृत', 'कफ', 'हेज', 'आदी', 'विशुद्ध', 'हेरफेर', 'देरी', 'रजी', 'मकसद', 'मुर्गे', 'भाग।', 'सहयोग', 'क़रीबनक़रीबन', 'फोटोग्राफ़रों', 'शॉ', 'खामियों', 'हड्डी', 'निकट', 'मोबाईल', 'अनहोनी', 'तराशे', 'ऋग्वेद', 'चूर्णी', 'पारियां', 'रेड', 'बर्बाद', 'निराकार', 'विपक्षी', 'रिलयंस', 'गठबंधन', 'उन्मूलनको', 'नरेश', 'लेखक', 'सेवियों', 'साँयः', 'शिक्षकसंस्करण', 'बहकर', 'जये', 'मतानुसार', 'मेरी', 'जातिगत', 'अचऋऊण्श्छ्ष्छी', 'यज्ञानुष्ठान', 'जालीदार', 'दूरदर्शन', 'गा', 'घंटा', 'प्रौद्योगिकीय', 'वॉशिंग', 'होयसलेश्वर', 'बागबाग', 'खयाल', 'बुखार', 'बल', 'वासुदेव', 'मानवशरीर', 'उपयोगिता', 'आये', 'वतन।', 'वक्ताओं', 'अबुल', 'पीउ', 'जीवनशैली', 'हेस्टिग़्ज', 'तिबत', 'दीनएइलाही', 'गले', 'कंबल', 'वाइसराय', 'वाष्पीकरण', 'हतोत्साहित', 'श्रेय', 'चालीस', 'रामास्वामी', 'मंत्र', 'मिस्र', 'कारी', 'दूंगा', 'वास्तुशिल्प', 'मध्यस्थ', 'चोटी', 'लागु', 'परिवर्णी', 'लियोनार्डो', 'सामरिक', 'संक्षेप', 'मामलं', 'देखिये', 'किसी', 'समाजशास्त्रीय', 'त्योहार', '१०००', 'खनन', 'संस्थापित', 'बैठो।', 'बनते', 'वह', 'बढ़ावा', 'कर्मकाण्ड', 'लेट', 'क्षति', 'सीसा', 'देशबन्धु', 'अलीरजी', 'गणतंत्र', 'पड़ीं।', 'रिओ', 'हंसी', 'तोझुबूर', 'जलाकर', 'हिंसात्मक', 'हिंदुसऋऊण्श्छ्ष्तान', 'व्यापक', 'पंहुचा', 'हत्यारों', 'चेचेन्या', 'मकबरे', 'गोलमेज', 'मस्जिद', 'टटोलें', 'दशद्वार', 'सफाई', 'मौजूदगी', 'मलिन', 'कुंवर', 'निहित', 'कद्र', 'कलाकृति', 'विधिमान्य', 'त्त्व', 'तूफान', 'धान', 'वर्ण', 'परदे', 'पुनरावृत्ति', 'गुणसूत्र', 'रेट्रोफिट', 'ज़िंदा', 'लोगो', 'निपटारे', 'किराये', 'रुपरेखा', 'संस्किऋत', 'डॉक्टर', 'लगनी', 'थीं', 'दोतिहाई', 'लगता', 'न्यायपालिका', 'सीखते', 'कंदबों', 'टैक़्स', 'पैटर्न', 'वाणी', 'थायह', 'सन्देश', 'मार्गदर्शनों', 'लग', 'सुपरमैन', 'भारदारो', 'औरभीऔर', 'शिरकत', 'जनसाधारण', 'गौरव', 'तोहोलू', 'सिखाकर', 'चित्रकार', 'संप्रदायवाद', 'विकिरणों', 'मचाओ।', 'दुरूस्त', '५३७', 'सुप्रीमो', 'सिस्टेम्स', 'नेतासभी', 'चौदय्या', 'बना', 'लिखीं', 'ऊब', 'दलभाजपा', 'लीं', 'छोड़ो।', 'लीफलेट्स', 'को', 'सल्ल', 'जोडऋ', 'हुँ', 'गंभीरता', 'सीडियों', 'महा', 'सामजिक', 'नदियाँ', 'अग', 'कपूर', 'प्रतिक्रिया', 'सम्राट', 'डपयॊग', 'उपक्रम', 'बलजीत', 'देहव्यापारी', 'श्रेणीहिन्दू', 'परंपरा', 'प्रतिबंधित', 'अवधिहृ', 'यह्', 'आजाओ।', 'कनाडियन', 'कोई', '२३', 'जोसेफ', 'टंगस्टन', 'पहुऋचाता', 'मिथकों', 'कृतित्रम', 'सहचारि ...

# %%
english_vocab.insert(0, START_TOKEN) 
english_vocab.append(PADDING_TOKEN)
english_vocab.append(END_TOKEN)
print(english_vocab)
# Out:
# ['<START>', 'spirituality', 'tell', '1350', 'exyernal', 'office', 'field', 'disasters', 'hindienglish', 'koneri', 'subtropical', 'estranged', 'loksabha', 'cloister', 'krupacharya', 'san', 'wasted', 'ellora', 'wang', 'antenatal', 'receptions', 'housing', 'marking', 'financial', 'buffaloes', 'storm', 'processes', 'far', 'moves', 'crack', 'companion', 'vivekanand12th', 'chap', 'nandikeshwar', 'alert', 'tours', 'returned', 'collectively', 'abusers', 'mulayam', 'thrissur', 'interchangeably', 'obstructing', 'chickens', 'site', 'intake', 'pandavas', 'parvati', 'india', 'bhayander', 'snowball', 'factual', 'marvel', 'writerdevelopment', 'torn', 'lightful', '3member', 'supposing', 'prevent', 'polished', 'catch', 'uninspiring', '8th', 'rjd', 'antihindu', 'paidup', 'nonreligious', 'supermarkets', 'cicada', 'toothbrush', 'treats', 'frequencies', 'motheaten', '20000', 'conciliation', 'expiation', 'uncertain', 'bald', 'rudracharya', 'ajit', 'skeletons', 'subba', '2004', 'extenuating', 'sursagar', 'bharata', 'always', 'fifteen', '2003', 'collection', 'todaybritish', 'disloyal', 'hoped', 'statue', 'pawns', 'adult', 'effects', 'water', 'tongues', 'walking', 'liming', 'vimanas', 'routes', 'pigeon', 'complete', 'tulaja', 'observation', 'wwwtmjorg', 'pests', 'worship', 'impossible', 'lifethis', 'muslin', 'embarrassed', 'engines', 'adi', 'sophistry', 'mahendra', 'trade', 'procedural', 'deshbandhu', 'reshuffle', 'classified', 'doordarshan', 'robust', 'idealistic', 'crippled', 'extant', 'initiated', 'statistical', 'japanese', 'registered', 'monotheist', 'basins', 'govindharajulu', 'attainments', 'slavery', 'institutions', 'catapulted', 'prithvi', 'intimacy', 'withdraw', 'toughness', 'proven', 'suggests', 'cameroon', 'boli', 'intensely', 'assault', 'danceroom', 'dar', 'pulses', '60', '422crore', 'curved', 'dislocation', 'seicho', 'sittings', 'congress', 'invariably', 'ladhakh', 'arose', 'sures', 'lobar', 'protocol', 'knit', 'discussions', 'congested', 'weird', 'launching', 'reducing', 'facto', 'assistant', 'dynamics', 'swift', 'swang', 'hajarat', 'punjab', 'obligation', 'shifting', 'grey', 'evaporates', 'industrialization', 'outlook', 'metabolic', 'immunities', 'lightknowledge', 'islamic', 'optimistic', 'investment', 'acquired', 'ramakrishna', 'prohibition', 'delaware', 'mugal', 'chingleput', '29', 'joust', 'efficiency', 'motprola', 'terriorist', 'items', 'yashodhara', 'shuangeri', 'marks', 'rajagopal', 'kinchinjunga', 'adjournment', 'simplification', 'subordinate', 'effortlessly', 'nataraja', 'nevada', 'shot', 'prostration', 'parable', 'abcl', 'intermingled', 'passing', 'khalifas', 'atom', 'basrelief', 'themes', 'shankar', 'drudgery', 'purushottam', 'guerrilla', 'nahar', 'dreamentranced', 'gross', 'experimental', 'bali', '195556', 'beleaguered', 'fitzgerald', 'uptodate', 'that', 'demanding', 'opponent', 'rocks', 'proportionate', 'tremendous', 'untill', 'motor', 'virus', 'mewar', 'colossal', 'bombing', 'archaic', 'sinkhandhar', 'street', 'competition', 'violent', 'korey', 'wealthy', 'rumor', 'communications', 'isd', '106', 'diseaseaccording', 'dissatisfied', 'curve', 'ayurveda', 'arya', 'lyall', 'rhetoric', 'appeals', 'proove', 'quacks', 'closed', 'souvenirs', 'hooghly', 'equipments', 'baap', 'glare', 'om', 'caveats', 'parsouli', 'vital', 'aback', 'underside', 'webpages', 'metallic', 'prabhupad', 'lashes', 'relies', 'compassion', 'removed', 'confusing', 'disabilities', 'statutory', '25980', 'vary', 'societiesand', 'ache', 'window', 'camps', '310', 'ponds', 'beamed', 'unwithered', 'proposed', 'grain', 'contemporaries', 'presenting', 'parliament', 'fateh', 'vases', 'other', 'temitiye', 'pharmaceutical', 'o3', 'urn', 'photos', 'ferrotungsten', 'legislate', 'treaty', 'selfrespect', 'communist', 'souls', 'varsovato', 'acquire', '110', '3300', 'kulti', 'profusions', 'costly', 'animalbased', 'purul', 'reversal', 'estimates', 'ambition', 'shri', 'similarly', 'negligible', 'sesherkavita', 'verma', 'digged', 'textile', 'walls', 'catalog', 'morefor', 'ghaughat', ...

# %%
index_to_hindi = {k:v for k,v in enumerate(hindi_vocab)}
hindi_to_index = {v:k for k,v in enumerate (hindi_vocab)}
index_to_english = {k:v for k,v in enumerate (english_vocab)}
english_to_index = {v:k for k,v in enumerate(english_vocab)}

# %%
index_to_hindi
# Out:
# {0: '<START>',
#  1: 'हवाईजहाज़',
#  2: 'पुस्तकें',
#  3: 'क्रिसेंट',
#  4: 'शोधसमूह',
#  5: 'अभिन्न',
#  6: 'कर्णकूट',
#  7: 'गुजरी',
#  8: 'हैंसेल',
#  9: 'प्रत्याशी',
#  10: 'बल्लेबाज',
#  11: 'वेबवार्ता',
#  12: 'इच्छामती',
#  13: 'रूपाकार',
#  14: 'साम्यवादी',
#  15: 'हाथः',
#  16: '१६००',
#  17: 'चोला',
#  18: 'नागपुर',
#  19: 'युद्धग्रस्त',
#  20: 'साधारणत',
#  21: 'खिताब',
#  22: 'आर्गनिक',
#  23: 'मेजबान',
#  24: 'ज़ारी',
#  25: 'गिरनी',
#  26: 'रनो',
#  27: 'शोले',
#  28: 'समाविष्ट',
#  29: 'भागवती',
#  30: 'पेशकश',
#  31: 'अवलोकन',
#  32: 'एपीजे',
#  33: 'आज़ादी',
#  34: 'इज़्जत',
#  35: 'स्थगन',
#  36: 'गुणों',
#  37: 'रेसियल',
#  38: 'अंधेर',
#  39: 'चमत्कार',
#  40: 'कटाई',
#  41: 'टोरी',
#  42: 'ग़लतफ़ैमी',
#  43: 'सलहमशविरा',
#  44: 'सुलझाने',
#  45: 'जाद',
#  46: 'कुरआन',
#  47: 'अहमियत',
#  48: 'डेनिश',
#  49: 'पंत',
#  50: 'टिहरी',
#  51: 'प्रजातियां',
#  52: 'कुडई',
#  53: 'हुमायुं',
#  54: 'एकदूसरे',
#  55: 'कॉण्ट्रैक्ट',
#  56: 'बताया।',
#  57: 'पहाड़ी',
#  58: 'अमोनिया',
#  59: 'ञुनेरल्',
#  60: 'क्रमांक',
#  61: 'प्रांतो',
#  62: 'चर्चाओं',
#  63: 'संवेदनशील',
#  64: 'भार',
#  65: 'सट्',
#  66: 'बनेगा',
#  67: 'पत्तनों',
#  68: 'रसायन',
#  69: 'भुलने',
#  70: 'रह',
#  71: 'अखबारों',
#  72: 'एमी',
#  73: 'बुनें',
#  74: 'धुए',
#  75: 'बधाईयाँ।',
#  76: '६३२',
#  77: 'अधिरथ',
#  78: 'अन्योन्य',
#  79: 'आन्दोलन',
#  80: 'दूतावास',
#  81: 'रक्षात्मक',
#  82: 'आयोजित',
#  83: 'छोड़ूँ',
#  84: 'बहुदेववाद',
#  85: 'गुच्छे',
#  86: 'नाभा',
#  87: 'नौकरियां',
#  88: 'विकृत',
#  89: 'चोगा',
#  90: 'सॉफ्टवेर',
#  91: 'ललीतपुर',
#  92: 'वैश्विक',
#  93: 'नववर्ष',
#  94: 'गफलत',
#  95: 'उसकाउसकी',
#  96: 'चाहिएफर्श',
#  97: 'नवीकरणीय',
#  98: 'नीहार',
#  99: '६७वीं',
#  100: 'निकोबार',
#  101: 'करीगर',
#  102: 'खोखर',
#  103: 'लीथियमबहुलक',
#  104: 'अरण्यकपर्व',
#  105: 'आतंकवादी',
#  106: 'सैनिक',
#  107: 'नाचना',
#  108: 'योग़्यता',
#  109: 'कोसों',
#  110: 'केंचुआ',
#  111: 'सुपरमार्केट',
#  112: 'क्रियान्वयन',
#  113: 'व्यग्रता',
#  114: 'ऋऋपिछले',
#  115: 'संरक्षण',
#  116: 'उठा।',
#  117: 'सनकी',
#  118: 'अध्यक्षसभापति',
#  119: 'अग्रेषित',
#  120: 'बर्लिन',
#  121: 'परिणामों',
#  122: 'घुअर्डिअन्',
#  123: 'राजग',
#  124: 'थूक',
#  125: 'गोइथे',
#  126: 'उत्पन्न',
#  127: 'विमोचन',
#  128: 'पत्रिका',
#  129: 'बोलिए।',
#  130: 'चारा',
#  131: 'रवीन्द्रनाथआधुनिक',
#  132: 'विचलित',
#  133: 'माऋग',
#  134: 'सत्य',
#  135: 'एकत्र',
#  136: 'ओलती',
#  137: 'कीटों',
#  138: 'भरी।',
#  139: 'अनुच्छेद',
#  140: 'अक्षत',
#  141: 'दार्शनिक',
#  142: 'फैलने',
#  143: 'एक्सचेंज',
#  144: 'अनोखी',
#  145: 'उदारवादी',
#  146: 'बड़',
#  147: 'सुहृद',
#  148: 'प्रतिकारक',
#  149: 'काक़्स',
#  150: 'सर्वव्यापी',
#  151: 'अवैध',
#  152: 'वाष्पशील',
#  153: 'महमूब',
#  154: 'लल',
#  155: 'अतंराल',
#  156: 'सौदे',
#  157: 'रति',
#  158: 'उदात्त',
#  159: 'युवकयुवतियां',
#  160: 'दीर्घकाल',
#  161: 'कुआललंपुर',
#  162: '२००१।',
#  163: 'ब्रौंज',
#  164: 'दुनिया।',
#  165: 'गुस्से',
#  166: 'प्रयोजन',
#  167: 'कुशलता',
#  168: 'प्रवाहों',
#  169: 'महेंद्रवाड़ी',
#  170: 'सीखी',
#  171: 'धर्मगुरु',
#  172: 'सारा',
#  173: 'हैइसमें',
#  174: 'करवाता',
#  175: 'फौजों',
#  176: 'श्रेणीसंस्कृत',
#  177: 'कफ',
#  178: 'हेज',
#  179: 'आदी',
#  180: 'विशुद्ध',
#  181: 'हेरफेर',
#  182: 'देरी',
#  183: 'रजी',
#  184: 'मकसद',
#  185: 'मुर्गे',
#  186: 'भाग।',
#  187: 'सहयोग',
#  188: 'क़रीबनक़रीबन',
#  189: 'फोटोग्राफ़रों',
#  190: 'शॉ',
#  191: 'खामियों',
#  192: 'हड्डी',
#  193: 'निकट',
#  194: 'मोबाईल',
#  195: 'अनहोनी',
#  196: 'तराशे',
#  197: 'ऋग्वेद',
#  198: 'चूर्णी',
#  199: 'पारियां',
#  200: 'रेड',
#  201: 'बर्बाद',
#  202: 'निराकार',
#  203: 'विपक्षी',
#  204: 'रिलयंस',
#  205: 'गठबंधन',
#  206: 'उन्मूलनको',
#  207: 'नरेश',
#  208: 'लेखक',
#  209: 'सेवियों',
#  210: 'साँयः',
#  211: 'शिक्षकसंस्करण',
#  212: 'बहकर',
#  213: 'जये',
#  214: 'मतानुसार',
#  215: 'मेरी',
#  216: 'जातिगत',
#  217: 'अचऋऊण्श्छ्ष्छी',
#  218: 'यज्ञानुष्ठान',
#  219: 'जालीदार',
#  220: 'दूरदर्शन',
#  221: 'गा',
#  222: 'घंटा',
#  223: 'प्रौद्योगिकीय',
#  224: 'वॉशिंग',
#  225: 'होयसलेश्वर',
#  226: 'बागबाग',
#  227: 'खयाल',
#  228: 'बुखार',
#  229: 'बल',
#  230: 'वासुदेव',
#  231: 'मानवशरीर',
#  232: 'उपयोगिता',
#  233: 'आये',
#  234: 'वतन।',
#  235: 'वक्ताओं',
#  236: 'अबुल',
#  237: 'पीउ',
#  238: 'जीवनशैली',
#  239: 'हेस्टिग़्ज',
#  240: 'तिबत',
#  241: 'दीनएइलाही',
#  242: 'गले',
#  243: 'कंबल',
#  244: 'वाइसराय',
#  245: 'वाष्पीकरण',
#  246: 'हतोत्साहित',
#  247: 'श्रेय',
#  248: 'चालीस',
#  249: 'रामास्वामी',
#  250: 'मंत्र',
#  251: 'मिस्र',
#  252: 'कारी',
#  253: 'दूंगा',
#  254: 'वास्तुशिल्प',
#  255: 'मध्यस्थ',
#  256: 'चोटी',
#  257: 'लागु',
#  258: 'परिवर्णी',
#  259: 'लियोनार्डो',
#  260: 'सामरिक',
#  261: 'संक्षेप',
#  262: 'मामलं',
#  263: 'देखिये',
#  264: 'किसी',
#  265: 'समाजशास्त्रीय',
#  266: 'त्योहार',
#  267: '१०००',
#  268: 'खनन',
#  269: 'संस्थापित',
#  270: 'बैठो।',
#  271: 'बनते',
#  272: 'वह',
#  273: 'बढ़ावा',
#  274: 'कर्मकाण्ड',
#  275: 'लेट',
#  276: 'क्षति',
#  277: 'सीसा',
#  278: 'देशबन्धु',
#  279: 'अलीरजी',
#  280: 'गणतंत्र',
#  281: 'पड़ीं।',
#  282: 'रिओ',
#  283: 'हंसी',
#  284: 'तोझुबूर',
#  285: 'जलाकर',
#  286: 'हिंसात्मक',
#  287: 'हिंदुसऋऊण्श्छ्ष्तान',
#  288: 'व्यापक',
#  289: 'पंहुचा',
#  290: 'हत्यारों',
#  291: 'चेचेन्या',
#  292: 'मकबरे',
#  293: 'गोलमेज',
#  294: 'मस्जिद',
#  295: 'टटोलें',
#  296: 'दशद्वार',
#  297: 'सफाई',
#  298: 'मौजूदगी',
#  299: 'मलिन',
#  300: 'कुंवर',
#  301: 'निहित',
#  302: 'कद्र',
#  303: 'कलाकृति',
#  304: 'विधिमान्य',
#  305: 'त्त्व',
#  306: 'तूफान',
#  307: 'धान',
#  308: 'वर्ण',
#  309: 'परदे',
#  310: 'पुनरावृत्ति',
#  311: 'गुणसूत्र',
#  312: 'रेट्रोफिट',
#  313: 'ज़िंदा',
#  314: 'लोगो',
#  315: 'निपटारे',
#  316: 'किराये',
#  317: 'रुपरेखा',
#  318: 'संस्किऋत',
#  319: 'डॉक्टर',
#  320: 'लगनी',
#  321: 'थीं',
#  322: 'दोतिहाई',
#  323: 'लगता',
#  324: 'न्यायपालिका',
#  325: 'सीखते',
#  326: 'कंदबों',
#  327: 'टैक़्स',
#  328: 'पैटर्न',
#  329: 'वाणी',
#  330: 'थायह',
#  331: 'सन्देश',
#  332: 'मार्गदर्शनों',
#  333: 'लग',
#  334: 'सुपरमैन',
#  335: 'भारदारो',
#  336: 'औरभीऔर',
#  337: 'शिरकत',
#  338: 'जनसाधारण',
#  339: 'गौरव',
#  340: 'तोहोलू',
#  341: 'सिखाकर',
#  342: 'चित्रकार',
#  343: 'संप्रदायवाद',
#  344: 'विकिरणों',
#  345: 'मचाओ।',
#  346: 'दुरूस्त',
#  347: '५३७',
#  348: 'सुप्रीमो',
#  349: 'सिस्टेम्स',
#  350: 'नेतासभी',
#  351: 'चौदय्या',
#  352: 'बना',
#  353: 'लिखीं',
#  354: 'ऊब',
#  355: 'दलभाजपा',
#  356: 'लीं',
#  357: 'छोड़ो।',
#  358: 'लीफलेट्स',
#  359: 'को',
#  360: 'सल्ल',
#  361: 'जोडऋ',
#  362: 'हुँ',
#  363: 'गंभीरता',
#  364: 'सीडियों',
#  365: 'महा',
#  366: 'सामजिक',
#  367: 'नदियाँ',
#  368: 'अग',
#  369: 'कपूर',
#  370: 'प्रतिक्रिया',
#  371: 'सम्राट',
#  372: 'डपयॊग',
#  373: 'उपक्रम',
#  374: 'बलजीत',
#  375: 'देहव्यापारी',
#  376: 'श्रेणीहिन्दू',
#  377: 'परंपरा',
#  378: 'प्रतिबंधित',
#  379: 'अवधिहृ',
#  380: 'यह्',
#  381: 'आजाओ।',
#  382: 'कनाडियन',
#  383: 'कोई',
#  384: '२३',
#  385: 'जोसेफ',
#  386: 'टंगस्टन',
#  387: 'पहुऋचाता',
#  388: 'मिथकों',
#  389: 'कृतित्रम',
#  390: 'सहचारिता',
#  391: 'भट्टी',
#  392: 'स्जिलेस्की',
#  393: 'विस्मित',
#  394: 'नरसिंह',
#  395: 'द्रविड़',
#  396: 'रूपी',
#  397: 'उत्थन',
#  398: 'सदियां',
#  399: 'धनी',
#  400: 'एकीकृत',
#  401: 'मुख',
#  402: 'भेजे।',
#  403: 'महानगरों',
#  404: 'कंधा',
#  405: 'देखें',
#  406: 'कविताओं',
#  407: 'विश्ववास',
#  408: 'स्वर्णिम',
#  409: 'सुदूर',
#  410: 'दूध',
#  411: 'खरीददारी',
#  412: 'सिखाते',
#  413: 'तकनीकी',
#  414: 'नवीनीकृत',
#  415: 'उपके',
#  416: 'सिन्डिकेशन',
#  417: 'वें',
#  418: 'देगा।',
#  419: 'बोर्ड़',
#  420: 'किसे',
#  421: 'हैंएक',
#  422: 'समाहित',
#  423: 'जिंदगीया',
#  424: 'आज़ाद',
#  425: 'हमीदा',
#  426: 'बांटी',
#  427: 'उमसभरी',
#  428: 'बढेतरी',
#  429: 'मनोनीत',
#  430: 'भूलिए',
#  431: 'भी',
#  432: 'अपौइंटमेंट',
#  433: 'विस्तारपूर्वक',
#  434: 'ह्रदय',
#  435: 'अवरूद्ध',
#  436: 'चौरस',
#  437: 'औलद',
#  438: 'हालाँकि',
#  439: 'ऊबी',
#  440: 'इश्रीनिवास',
#  441: 'इच्टिम्',
#  442: 'कोपनहेगन',
#  443: 'संध',
#  444: 'प्रक्षिपऋऊण्श्छ्ष्त',
#  445: 'ङ्',
#  446: 'राजगृह',
#  447: 'अनुसन्धान',
#  448: 'दुर्बलता',
#  449: 'ड्मूने',
#  450: 'गईं',
#  451: 'आते',
#  452: 'वर्गगता',
#  453: 'इतिहास',
#  454: 'कलशों',
#  455: 'संयोगवश',
#  456: 'चढ़ता',
#  457: 'भरतपुर',
#  458: 'खींचकर',
#  459: 'खोलिए।',
#  460: 'सुचिक्कनता',
#  461: 'क़ैदी',
#  462: 'एडज़',
#  463: 'कलाचातुरी',
#  464: 'महंगाई',
#  465: 'सऋऊण्श्छ्ष्वार्थपूर्ण',
#  466: 'अधिषऋऊण्श्छ्ष्ठान',
#  467: 'व्यि',
#  468: 'ख़र्च',
#  469: 'मार',
#  470: 'भारित',
#  471: 'वर्षगांठ',
#  472: 'दांत',
#  473: 'धरा',
#  474: 'अपारंपरिक',
#  475: 'सूचकांक',
#  476: 'सिक्के',
#  477: 'निराश',
#  478: 'ढूंढना',
#  479: 'सन्ताने।',
#  480: 'माफ',
#  481: 'तिब्बत',
#  482: 'स्मृतिकेंद्रित',
#  483: 'असुरक्षित',
#  484: 'किताबे',
#  485: 'संविधानों',
#  486: 'इनक',
#  487: 'आर्किटेक्टों',
#  488: 'चोलकाल',
#  489: 'जमेजमाये',
#  490: 'प्लीज़।',
#  491: 'थप्पड़',
#  492: 'किन्तु',
#  493: 'असंतोष',
#  494: '१८५',
#  495: 'सामानऋद्दय',
#  496: 'बुरे',
#  497: 'नालियों',
#  498: 'मोतियों',
#  499: 'संग्रहकर्ता',
#  500: 'लाभदायक',
#  501: 'फ़ोटोसिन्थ',
#  502: 'पदयात्राएँ',
#  503: 'अपवाद',
#  504: 'डूबते',
#  505: 'आता।',
#  506: 'उपासना',
#  507: 'क़ब्र',
#  508: 'घने',
#  509: 'छोम्पेन्सटिओन्',
#  510: 'रूपए',
#  511: 'प्रचण्ड',
#  512: 'आत्मिक',
#  513: 'र्थे',
#  514: 'परिवर्तन',
#  515: 'मुमताज',
#  516: 'डॉ',
#  517: 'करनेवालों',
#  518: 'पालक',
#  519: 'सको',
#  520: 'वी',
#  521: 'इंडिक',
#  522: 'उमीदों',
#  523: 'ली',
#  524: 'सहयोगी',
#  525: 'रक़्त',
#  526: 'आनर्स',
#  527: 'ग्रेनाइट',
#  528: 'बरदाशऋऊण्श्छ्ष्त',
#  529: 'पदार्फाश',
#  530: 'अभिरूचि',
#  531: 'विख़्यात',
#  532: 'चिल्लाने',
#  533: 'संगठनों',
#  534: 'मीटर१४४००',
#  535: 'इजाजत',
#  536: 'महिलायें',
#  537: 'छठा',
#  538: 'अंजीर',
#  539: 'आर्कषणों',
#  540: 'स्टम्पड',
#  541: 'एलर्जी',
#  542: 'गड़बड़ी',
#  543: 'अस्पताल',
#  544: 'फेंकना',
#  545: 'ऋणमाफ़ी',
#  546: 'द्वंद्व',
#  547: 'पेनसिल',
#  548: 'कपड़ों',
#  549: 'हाल',
#  550: 'ड्राइवहुक',
#  551: 'पहुंचाई',
#  552: 'अक्षम्य',
#  553: 'अन्त।',
#  554: 'कृष्णा',
#  555: 'मुय',
#  556: 'व्यायाओं',
#  557: 'घरमोहल्ले',
#  558: 'सुविदाओं',
#  559: 'सिरपैर',
#  560: 'अप्रत्यक्ष',
#  561: 'आयताकार',
#  562: 'दानों',
#  563: 'प्रोटोकॉल',
#  564: 'स्त्रियाँ',
#  565: 'राजगुरू',
#  566: 'जमीनआसमान',
#  567: 'इंद्रजीत',
#  568: 'जुड़ने',
#  569: 'ज्ह्रनों',
#  570: 'अयस्कों',
#  571: 'श्रेणीअंतरजाल',
#  572: 'नैवेद्य',
#  573: 'दिलों',
#  574: 'रहती',
#  575: 'ईदउलअज़्हा',
#  576: 'मजहब',
#  577: 'हटीं',
#  578: 'उठानी',
#  579: 'लगभाग',
#  580: 'भेदी',
#  581: '२००६',
#  582: 'ऊर्ध्वागामी',
#  583: 'मोडऋ',
#  584: 'थेब्रिटिश',
#  585: 'मकानों',
#  586: 'घंटों',
#  587: 'रुकी',
#  588: 'यूनीवर्सल',
#  589: 'निकेतन',
#  590: 'स्कोरकार्ड',
#  591: 'भड़क',
#  592: 'गोपीलीला',
#  593: '१९९११९९२',
#  594: 'मोजाइक',
#  595: 'विरक्त',
#  596: 'संकरों',
#  597: 'विवाह',
#  598: 'डाक्टर',
#  599: 'अभियंत्रिकी',
#  600: 'कीचड़',
#  601: 'बीकानेरी',
#  602: 'दबाना',
#  603: 'युनान',
#  604: 'नकंशे',
#  605: 'शिपयार्ड',
#  606: 'बराबरी',
#  607: 'समझोता',
#  608: 'दवाइयां',
#  609: 'उत्तरदायी',
#  610: 'बनी',
#  611: 'चिपकाई',
#  612: 'क्रीजों',
#  613: 'यथापारित',
#  614: 'कौतूहल',
#  615: 'ऐफ्',
#  616: 'ख़रीदने',
#  617: 'रूद्रवलीश्वरम',
#  618: 'घुसते',
#  619: 'शफीक',
#  620: 'लहरसी',
#  621: 'संकेद्रिंत',
#  622: 'खींज',
#  623: 'कांगो',
#  624: 'सवा',
#  625: 'ड़ोड़ा',
#  626: 'जताई',
#  627: 'सर्व',
#  628: 'नव्योत्तर',
#  629: 'गुणवत्ता',
#  630: 'कनारी',
#  631: 'मालबार',
#  632: 'अविच्छिन्न',
#  633: 'अंश',
#  634: 'सीकरी',
#  635: 'चश्मदीद',
#  636: 'परखने',
#  637: 'चाहिए',
#  638: 'नासिक',
#  639: 'तंदुरुस्त',
#  640: 'ग्रासिम',
#  641: 'कलकत्ता',
#  642: 'राखी',
#  643: 'समुदाया',
#  644: 'एं',
#  645: 'फासीवाद',
#  646: 'हलका',
#  647: 'सुनीता',
#  648: 'स्तनधारी',
#  649: 'आइसोसाइनेट',
#  650: 'मात्सुमोतो',
#  651: 'स्रोतों',
#  652: 'बहू',
#  653: 'शऋनक',
#  654: 'श्रृंखला',
#  655: 'नीले',
#  656: 'स्याही',
#  657: 'सत्यावोलु',
#  658: 'सहानुभूति',
#  659: 'उत्कृष्टता',
#  660: 'प्रतिपादित',
#  661: 'मुड़कर',
#  662: 'खानऐखाना',
#  663: 'विद्वानों',
#  664: 'कर्तव्यों',
#  665: 'तोड़ेगा।',
#  666: 'पद्धतियों',
#  667: 'परवान',
#  668: 'रोते',
#  669: 'क्रिस्टॉफर',
#  670: 'सोक्रेट्स',
#  671: 'उपनगर',
#  672: 'ग्रंथों',
#  673: 'थीकि',
#  674: 'सलाहकार',
#  675: 'फ्खू',
#  676: 'खुदे',
#  677: 'साढे',
#  678: 'रूपात्मक',
#  679: 'वृहततर',
#  680: 'अबाध',
#  681: 'सूअरों',
#  682: 'सुदार',
#  683: 'मजदूरों',
#  684: 'तस्वीर',
#  685: 'दोहराया',
#  686: 'मनस्थिति',
#  687: 'निष्फल',
#  688: 'विरुद्ध',
#  689: 'सत्तासीन',
#  690: 'सीधेसीधे',
#  691: 'मातृहीन',
#  692: 'बिजली',
#  693: 'विलियम',
#  694: 'मलयाली',
#  695: 'फ़ैसला',
#  696: 'समझाया।',
#  697: 'ं',
#  698: 'तिलहन',
#  699: 'लॅ',
#  700: 'सांस',
#  701: 'बन्धन',
#  702: 'डख्याङ',
#  703: 'सोचें',
#  704: 'बचा',
#  705: 'मेहसूस',
#  706: 'दिख',
#  707: 'देवर',
#  708: 'पीपीएम',
#  709: 'संश्लेषणमें',
#  710: 'उपसंहार',
#  711: 'कन्ट्रोल',
#  712: 'मुसोलिनी',
#  713: 'ब्याह',
#  714: 'चुराना',
#  715: 'घृणा',
#  716: 'छोम्मुनिट्य्',
#  717: 'वॉर्मिंग',
#  718: 'छोटेसे',
#  719: 'घटती',
#  720: 'महाविद्यालय',
#  721: 'जेसप',
#  722: 'आरएसएस',
#  723: 'ऊँगली',
#  724: 'भूमिका',
#  725: 'साधुओं',
#  726: 'इस्पात',
#  727: 'अचऋऊण्श्छ्ष्छे',
#  728: 'यूनाइटेड',
#  729: 'कश्फ़उलमहजूब',
#  730: 'डिंब',
#  731: 'सबल',
#  732: 'एंजिलिस',
#  733: 'मालूम',
#  734: 'वारदात',
#  735: 'घटकों',
#  736: 'तात्कालिक',
#  737: 'दाँतों',
#  738: 'शुभ',
#  739: 'बुद्धिजीवियों',
#  740: 'रेखाएँ',
#  741: 'अल',
#  742: 'श्वेता',
#  743: 'दात',
#  744: 'आप',
#  745: 'खुलना',
#  746: 'शामिल',
#  747: 'धर्मसंगठन',
#  748: 'चौकी',
#  749: 'ज़्यों',
#  750: 'लेजाने',
#  751: 'इनऋऊण्श्छ्ष्हीं',
#  752: 'वाले',
#  753: 'प्रचारित',
#  754: 'सुक्ष्म',
#  755: 'पासे',
#  756: 'सालभर',
#  757: 'अनुशासनात्मक',
#  758: 'जीतने',
#  759: 'कौटुंबिक',
#  760: 'पाठक',
#  761: 'च्रेडिट्स्',
#  762: 'हफ्तों',
#  763: 'दुरबीनों',
#  764: 'एटीपी',
#  765: 'भूमध्यरेखा',
#  766: 'कार्यकर्ताओं',
#  767: 'तैया',
#  768: 'मंड़पों',
#  769: 'ग्रहित',
#  770: 'हृदय',
#  771: 'बीमाएजेंट',
#  772: 'द्रव्यों',
#  773: 'पछाड़',
#  774: 'नऋ',
#  775: 'इनसे',
#  776: 'मनीषी',
#  777: 'हांलाकि',
#  778: 'अलीमुद्दीन',
#  779: 'रेमी',
#  780: 'राजनितिक',
#  781: 'फायदा',
#  782: 'स्प्रे',
#  783: 'शाहवली',
#  784: 'मजबुत',
#  785: 'श्रमिकों',
#  786: 'संबंध',
#  787: 'नेत्रहीन',
#  788: 'जाम',
#  789: 'हॉल',
#  790: 'सत्यजीत',
#  791: 'स्वयंवर',
#  792: 'शब्दों',
#  793: 'मनाई',
#  794: 'डरबन',
#  795: 'भ',
#  796: 'समन्वय',
#  797: 'पैग़म्बर',
#  798: 'लाइलाज',
#  799: 'आनेवाले',
#  800: 'हमूदउर',
#  801: 'बहुधा',
#  802: 'अतारांकित',
#  803: 'इनमें',
#  804: 'लड़नेझगड़ने',
#  805: 'चश्मे',
#  806: 'मारने',
#  807: 'यथासंभव',
#  808: 'परियोजनाएं',
#  809: 'सुनेंगे',
#  810: 'परशियन',
#  811: 'गोहत्या',
#  812: 'गीले',
#  813: 'उपभोक्ताओं',
#  814: 'साक्ष्यों',
#  815: 'वारेन',
#  816: 'हिंसायाम',
#  817: 'हेतु',
#  818: 'उमर',
#  819: 'युवक',
#  820: 'तिलचट्टा',
#  821: 'फूलगोभी',
#  822: 'खेता',
#  823: 'वैसे',
#  824: 'वरन्',
#  825: 'फंचीं',
#  826: 'खुल्ला',
#  827: 'चूकिं',
#  828: 'कुछ',
#  829: 'विचारण',
#  830: 'कि',
#  831: 'जुलाई',
#  832: 'तोप',
#  833: 'विट्रिअस',
#  834: 'इंगलैंड',
#  835: 'मंत्रियों',
#  836: 'अदवाईस',
#  837: 'जला',
#  838: 'छेड़ी',
#  839: 'अंत्यसंस्कार',
#  840: 'क्षणिक',
#  841: 'पिताजी',
#  842: 'बीमारियां',
#  843: 'होगे',
#  844: 'मिशिगन',
#  845: 'कूदने',
#  846: 'किसलिए',
#  847: 'देनेवाली',
#  848: 'मूर्तिकलागत',
#  849: 'बढ़ाती',
#  850: 'नौकरियाँ',
#  851: 'हूई',
#  852: 'टोस',
#  853: 'अप्पम',
#  854: 'संघर्षरत',
#  855: 'हत्याओं',
#  856: 'खरीदा।',
#  857: 'आकांक्षा',
#  858: 'स्टूल',
#  859: 'रखेगा',
#  860: 'दोस्त',
#  861: 'ज्वार',
#  862: 'सम्मिश्रण',
#  863: 'विधवा',
#  864: 'कोर्निस',
#  865: 'शांतिनिकेतन',
#  866: 'क्लेम',
#  867: 'विश्व',
#  868: 'पर्वतों',
#  869: 'प्रतिवेदन',
#  870: 'अवश्य',
#  871: 'ऋच',
#  872: 'कृतिदेव',
#  873: 'आना।',
#  874: 'पोर्टल',
#  875: 'हिमवंत',
#  876: 'शंकर्स',
#  877: 'रातदिन',
#  878: 'खेले',
#  879: 'ज़माने',
#  880: 'इबन',
#  881: 'रखना',
#  882: 'थूकेगा',
#  883: 'बुद्धवार',
#  884: 'बध्दता',
#  885: 'प्रावधान',
#  886: 'सेण्टीमीटर',
#  887: 'वापस',
#  888: 'चाहो',
#  889: 'आपरेशनों',
#  890: 'क्रीज',
#  891: 'राहत',
#  892: 'गारिमा',
#  893: 'मोर्चा',
#  894: 'उठाया।',
#  895: 'लगभग',
#  896: 'रिसीवर',
#  897: 'अपहृत',
#  898: 'जन्मे',
#  899: 'शेयरों',
#  900: 'हड़तालों',
#  901: 'चलाई',
#  902: 'यंग',
#  903: 'विज्ञानी',
#  904: 'ऑनलाइन',
#  905: 'निवासियों',
#  906: 'टिप्पणियों',
#  907: 'असमर्थ',
#  908: 'शोरशराबे',
#  909: 'चोरों',
#  910: 'पोर्फिरियो',
#  911: 'हक़',
#  912: 'ड़ीपीसी',
#  913: 'विश्लेषणॊं',
#  914: 'ठीक',
#  915: 'पेशियों',
#  916: 'अमर',
#  917: 'कुर्नूल',
#  918: 'मॉड़ल',
#  919: 'छोटीमोटी',
#  920: 'खुलते',
#  921: 'उदसे',
#  922: 'बीसवी',
#  923: 'कैबिनेट',
#  924: 'रहस्यानुभूति',
#  925: 'फेकते',
#  926: 'प्रतिहारी',
#  927: 'पुस्तक',
#  928: 'टहलें।',
#  929: 'जोहंनें',
#  930: 'यादि',
#  931: 'टाटा',
#  932: 'अवगत',
#  933: 'आनंद',
#  934: 'पकाया।',
#  935: 'बोतलों',
#  936: 'जनसंख़्या',
#  937: 'कचऋऊण्श्छ्ष्चे',
#  938: 'थोड़ाबहुत',
#  939: 'तकनीकों',
#  940: 'क्षेत्रीय',
#  941: 'हैइसके',
#  942: 'नियंत्रित',
#  943: 'जैसे',
#  944: 'मेभी',
#  945: 'पायी',
#  946: 'दम',
#  947: 'श्रीलंकाई',
#  948: 'छत',
#  949: 'माऽ',
#  950: 'असरे',
#  951: 'पेड',
#  952: 'चुनावों',
#  953: 'मिलकर',
#  954: 'सा',
#  955: 'सोया',
#  956: 'बुड़िकोट',
#  957: 'जीवन्तता',
#  958: 'पल्ले',
#  959: 'सारीकीसारी',
#  960: 'कारणों',
#  961: 'आवाजाही',
#  962: 'ननिहाल',
#  963: 'केंद्रीय',
#  964: 'जत',
#  965: 'प्रश्नों',
#  966: 'जगन्नाथदास',
#  967: 'हैसंभव',
#  968: 'स्वीकृत',
#  969: 'झिलता',
#  970: 'रूपया',
#  971: 'पंद्रहवीं',
#  972: 'निबंधों',
#  973: 'उत्तप्त',
#  974: 'प्रण',
#  975: 'दादीमाँ',
#  976: 'जवाब',
#  977: 'सालुशन',
#  978: 'आरजु',
#  979: 'दृश्य',
#  980: 'छूता',
#  981: 'प्रवाहित',
#  982: 'स्थानच्युत',
#  983: 'करिए',
#  984: 'छलांग',
#  985: 'बातें',
#  986: 'धर्मशास्त्र',
#  987: 'मत।',
#  988: 'सल्फ्यूरिक',
#  989: 'खालिस्तानी',
#  990: 'फ्लौस',
#  991: 'गतिविधियों',
#  992: 'अभिनन्दन',
#  993: 'प्रशंसनीय',
#  994: 'रेजिमेंट',
#  995: 'बूटेदार',
#  996: 'पढे',
#  997: 'समीक्षा',
#  998: 'महमूद',
#  999: 'संगीन',
#  ...}

# %%
index_to_english
# Out:
# {0: '<START>',
#  1: 'spirituality',
#  2: 'tell',
#  3: '1350',
#  4: 'exyernal',
#  5: 'office',
#  6: 'field',
#  7: 'disasters',
#  8: 'hindienglish',
#  9: 'koneri',
#  10: 'subtropical',
#  11: 'estranged',
#  12: 'loksabha',
#  13: 'cloister',
#  14: 'krupacharya',
#  15: 'san',
#  16: 'wasted',
#  17: 'ellora',
#  18: 'wang',
#  19: 'antenatal',
#  20: 'receptions',
#  21: 'housing',
#  22: 'marking',
#  23: 'financial',
#  24: 'buffaloes',
#  25: 'storm',
#  26: 'processes',
#  27: 'far',
#  28: 'moves',
#  29: 'crack',
#  30: 'companion',
#  31: 'vivekanand12th',
#  32: 'chap',
#  33: 'nandikeshwar',
#  34: 'alert',
#  35: 'tours',
#  36: 'returned',
#  37: 'collectively',
#  38: 'abusers',
#  39: 'mulayam',
#  40: 'thrissur',
#  41: 'interchangeably',
#  42: 'obstructing',
#  43: 'chickens',
#  44: 'site',
#  45: 'intake',
#  46: 'pandavas',
#  47: 'parvati',
#  48: 'india',
#  49: 'bhayander',
#  50: 'snowball',
#  51: 'factual',
#  52: 'marvel',
#  53: 'writerdevelopment',
#  54: 'torn',
#  55: 'lightful',
#  56: '3member',
#  57: 'supposing',
#  58: 'prevent',
#  59: 'polished',
#  60: 'catch',
#  61: 'uninspiring',
#  62: '8th',
#  63: 'rjd',
#  64: 'antihindu',
#  65: 'paidup',
#  66: 'nonreligious',
#  67: 'supermarkets',
#  68: 'cicada',
#  69: 'toothbrush',
#  70: 'treats',
#  71: 'frequencies',
#  72: 'motheaten',
#  73: '20000',
#  74: 'conciliation',
#  75: 'expiation',
#  76: 'uncertain',
#  77: 'bald',
#  78: 'rudracharya',
#  79: 'ajit',
#  80: 'skeletons',
#  81: 'subba',
#  82: '2004',
#  83: 'extenuating',
#  84: 'sursagar',
#  85: 'bharata',
#  86: 'always',
#  87: 'fifteen',
#  88: '2003',
#  89: 'collection',
#  90: 'todaybritish',
#  91: 'disloyal',
#  92: 'hoped',
#  93: 'statue',
#  94: 'pawns',
#  95: 'adult',
#  96: 'effects',
#  97: 'water',
#  98: 'tongues',
#  99: 'walking',
#  100: 'liming',
#  101: 'vimanas',
#  102: 'routes',
#  103: 'pigeon',
#  104: 'complete',
#  105: 'tulaja',
#  106: 'observation',
#  107: 'wwwtmjorg',
#  108: 'pests',
#  109: 'worship',
#  110: 'impossible',
#  111: 'lifethis',
#  112: 'muslin',
#  113: 'embarrassed',
#  114: 'engines',
#  115: 'adi',
#  116: 'sophistry',
#  117: 'mahendra',
#  118: 'trade',
#  119: 'procedural',
#  120: 'deshbandhu',
#  121: 'reshuffle',
#  122: 'classified',
#  123: 'doordarshan',
#  124: 'robust',
#  125: 'idealistic',
#  126: 'crippled',
#  127: 'extant',
#  128: 'initiated',
#  129: 'statistical',
#  130: 'japanese',
#  131: 'registered',
#  132: 'monotheist',
#  133: 'basins',
#  134: 'govindharajulu',
#  135: 'attainments',
#  136: 'slavery',
#  137: 'institutions',
#  138: 'catapulted',
#  139: 'prithvi',
#  140: 'intimacy',
#  141: 'withdraw',
#  142: 'toughness',
#  143: 'proven',
#  144: 'suggests',
#  145: 'cameroon',
#  146: 'boli',
#  147: 'intensely',
#  148: 'assault',
#  149: 'danceroom',
#  150: 'dar',
#  151: 'pulses',
#  152: '60',
#  153: '422crore',
#  154: 'curved',
#  155: 'dislocation',
#  156: 'seicho',
#  157: 'sittings',
#  158: 'congress',
#  159: 'invariably',
#  160: 'ladhakh',
#  161: 'arose',
#  162: 'sures',
#  163: 'lobar',
#  164: 'protocol',
#  165: 'knit',
#  166: 'discussions',
#  167: 'congested',
#  168: 'weird',
#  169: 'launching',
#  170: 'reducing',
#  171: 'facto',
#  172: 'assistant',
#  173: 'dynamics',
#  174: 'swift',
#  175: 'swang',
#  176: 'hajarat',
#  177: 'punjab',
#  178: 'obligation',
#  179: 'shifting',
#  180: 'grey',
#  181: 'evaporates',
#  182: 'industrialization',
#  183: 'outlook',
#  184: 'metabolic',
#  185: 'immunities',
#  186: 'lightknowledge',
#  187: 'islamic',
#  188: 'optimistic',
#  189: 'investment',
#  190: 'acquired',
#  191: 'ramakrishna',
#  192: 'prohibition',
#  193: 'delaware',
#  194: 'mugal',
#  195: 'chingleput',
#  196: '29',
#  197: 'joust',
#  198: 'efficiency',
#  199: 'motprola',
#  200: 'terriorist',
#  201: 'items',
#  202: 'yashodhara',
#  203: 'shuangeri',
#  204: 'marks',
#  205: 'rajagopal',
#  206: 'kinchinjunga',
#  207: 'adjournment',
#  208: 'simplification',
#  209: 'subordinate',
#  210: 'effortlessly',
#  211: 'nataraja',
#  212: 'nevada',
#  213: 'shot',
#  214: 'prostration',
#  215: 'parable',
#  216: 'abcl',
#  217: 'intermingled',
#  218: 'passing',
#  219: 'khalifas',
#  220: 'atom',
#  221: 'basrelief',
#  222: 'themes',
#  223: 'shankar',
#  224: 'drudgery',
#  225: 'purushottam',
#  226: 'guerrilla',
#  227: 'nahar',
#  228: 'dreamentranced',
#  229: 'gross',
#  230: 'experimental',
#  231: 'bali',
#  232: '195556',
#  233: 'beleaguered',
#  234: 'fitzgerald',
#  235: 'uptodate',
#  236: 'that',
#  237: 'demanding',
#  238: 'opponent',
#  239: 'rocks',
#  240: 'proportionate',
#  241: 'tremendous',
#  242: 'untill',
#  243: 'motor',
#  244: 'virus',
#  245: 'mewar',
#  246: 'colossal',
#  247: 'bombing',
#  248: 'archaic',
#  249: 'sinkhandhar',
#  250: 'street',
#  251: 'competition',
#  252: 'violent',
#  253: 'korey',
#  254: 'wealthy',
#  255: 'rumor',
#  256: 'communications',
#  257: 'isd',
#  258: '106',
#  259: 'diseaseaccording',
#  260: 'dissatisfied',
#  261: 'curve',
#  262: 'ayurveda',
#  263: 'arya',
#  264: 'lyall',
#  265: 'rhetoric',
#  266: 'appeals',
#  267: 'proove',
#  268: 'quacks',
#  269: 'closed',
#  270: 'souvenirs',
#  271: 'hooghly',
#  272: 'equipments',
#  273: 'baap',
#  274: 'glare',
#  275: 'om',
#  276: 'caveats',
#  277: 'parsouli',
#  278: 'vital',
#  279: 'aback',
#  280: 'underside',
#  281: 'webpages',
#  282: 'metallic',
#  283: 'prabhupad',
#  284: 'lashes',
#  285: 'relies',
#  286: 'compassion',
#  287: 'removed',
#  288: 'confusing',
#  289: 'disabilities',
#  290: 'statutory',
#  291: '25980',
#  292: 'vary',
#  293: 'societiesand',
#  294: 'ache',
#  295: 'window',
#  296: 'camps',
#  297: '310',
#  298: 'ponds',
#  299: 'beamed',
#  300: 'unwithered',
#  301: 'proposed',
#  302: 'grain',
#  303: 'contemporaries',
#  304: 'presenting',
#  305: 'parliament',
#  306: 'fateh',
#  307: 'vases',
#  308: 'other',
#  309: 'temitiye',
#  310: 'pharmaceutical',
#  311: 'o3',
#  312: 'urn',
#  313: 'photos',
#  314: 'ferrotungsten',
#  315: 'legislate',
#  316: 'treaty',
#  317: 'selfrespect',
#  318: 'communist',
#  319: 'souls',
#  320: 'varsovato',
#  321: 'acquire',
#  322: '110',
#  323: '3300',
#  324: 'kulti',
#  325: 'profusions',
#  326: 'costly',
#  327: 'animalbased',
#  328: 'purul',
#  329: 'reversal',
#  330: 'estimates',
#  331: 'ambition',
#  332: 'shri',
#  333: 'similarly',
#  334: 'negligible',
#  335: 'sesherkavita',
#  336: 'verma',
#  337: 'digged',
#  338: 'textile',
#  339: 'walls',
#  340: 'catalog',
#  341: 'morefor',
#  342: 'ghaughat',
#  343: 'occured',
#  344: 'melody',
#  345: 'input',
#  346: 'adjust',
#  347: 'shibboleth',
#  348: 'nicobarese',
#  349: 'prospered',
#  350: 'bhishma',
#  351: 'dimensions',
#  352: 'tactics',
#  353: 'rhythm',
#  354: 'conscientiously',
#  355: 'pickle',
#  356: 'pounding',
#  357: 'liberalism',
#  358: 'saving',
#  359: 'outskirts',
#  360: 'engage',
#  361: 'compact',
#  362: 'ummaid',
#  363: 'foot',
#  364: 'connections',
#  365: 'wallpapering',
#  366: 'superman',
#  367: 'sedatives',
#  368: 'ross',
#  369: 'alternative',
#  370: 'legislature',
#  371: 'writ',
#  372: 'kidding',
#  373: 'clever',
#  374: 'harmonic',
#  375: 'excluding',
#  376: 'tolerance',
#  377: 'korea',
#  378: 'bluecollar',
#  379: 'equipped',
#  380: '4',
#  381: 'tumbling',
#  382: 'aggressive',
#  383: 'test',
#  384: 'shopping',
#  385: 'jem',
#  386: '1929',
#  387: 'congratulate',
#  388: 'skilled',
#  389: 'diversity',
#  390: 'lodged',
#  391: 'squeeze',
#  392: '2500',
#  393: 'epiphany',
#  394: 'sakalesha',
#  395: 'molecule',
#  396: 'affiliation',
#  397: 'unitism',
#  398: 'requires',
#  399: 'forgetting',
#  400: 'threedimensional',
#  401: 'evaluate',
#  402: 'tyopologias',
#  403: 'inlaws',
#  404: 'transmission',
#  405: 'acidity',
#  406: 'cartoonists',
#  407: 'aatre',
#  408: 'doubtful',
#  409: 'pulav',
#  410: 'ours',
#  411: 'fieldthe',
#  412: 'early',
#  413: 'd',
#  414: 'dropped',
#  415: 'aggregate',
#  416: 'profession',
#  417: 'wronged',
#  418: 'boost',
#  419: 'reduces',
#  420: 'clamour',
#  421: 'dante',
#  422: 'mathematicians',
#  423: 'fox',
#  424: 'aristocratic',
#  425: 'ummer',
#  426: '1988along',
#  427: 'castles',
#  428: 'sic',
#  429: 'dhamma',
#  430: 'mahanandibordering',
#  431: 'symbols',
#  432: 'critical',
#  433: 'gripped',
#  434: 'imperialist',
#  435: 'researchers',
#  436: 'accumulate',
#  437: 'electors',
#  438: 'concentrations',
#  439: 'confused',
#  440: 'unity',
#  441: 'topped',
#  442: 'shut',
#  443: 'adoration',
#  444: 'ujaala',
#  445: 'websites',
#  446: 'deshmukh',
#  447: 'fifty',
#  448: '79',
#  449: '0001',
#  450: 'valley',
#  451: 'inside',
#  452: 'sugriv',
#  453: 'briefed',
#  454: 'copyright',
#  455: 'sony',
#  456: 'alauddin',
#  457: 'genotypic',
#  458: 'cutting',
#  459: 'eighty',
#  460: 'converge',
#  461: '2s',
#  462: 'nasiruddin',
#  463: 'powerful',
#  464: 'warden',
#  465: 'stallfed',
#  466: 'finger',
#  467: 'forcing',
#  468: 'inviting',
#  469: 'future',
#  470: 'gongsdrums',
#  471: 'rooms',
#  472: 'providing',
#  473: 'undertook',
#  474: 'trafficking',
#  475: 'mosaic',
#  476: 'bhushan',
#  477: 'demanded',
#  478: 'grandfather',
#  479: 'communication',
#  480: 'safeguarding',
#  481: 'consumables',
#  482: 'metempsychosis',
#  483: 'rotted',
#  484: 'pupae',
#  485: 'cold',
#  486: 'assam',
#  487: 'hiding',
#  488: 'retinopathy',
#  489: 'logic',
#  490: 'bazarcobbler',
#  491: '208',
#  492: 'pity',
#  493: 'reconciliation',
#  494: 'agoso',
#  495: 'ridiculous',
#  496: 'hec',
#  497: 'rivermouths',
#  498: 'completion',
#  499: 'relaxes',
#  500: 'concealed',
#  501: 'opaque',
#  502: 'socialist',
#  503: 'inorganic',
#  504: 'heavy',
#  505: 'acceptable',
#  506: 'settled',
#  507: 'employed',
#  508: 'oceans',
#  509: 'porfirio',
#  510: '1895',
#  511: 'portion',
#  512: 'shine',
#  513: 'majoritywhen',
#  514: '1613',
#  515: '127',
#  516: 'kisan',
#  517: 'saf',
#  518: 'supplied',
#  519: 'shahi',
#  520: 'scarcity',
#  521: 'gets',
#  522: 'merely',
#  523: 'besind',
#  524: 'kingdoms',
#  525: 'reflected',
#  526: 'worries',
#  527: 'indirectly',
#  528: 'vehicles',
#  529: 'sofomo',
#  530: 'natives',
#  531: 'pulkasi',
#  532: 'antiimperialist',
#  533: 'acknowledge',
#  534: 'across',
#  535: 'beings',
#  536: 'contributing',
#  537: 'ndtv',
#  538: 'swaroop',
#  539: 'glut',
#  540: 'senabjp',
#  541: 'surrounds',
#  542: 'bhandar',
#  543: 'plaster',
#  544: 'reduced',
#  545: 'negotiated',
#  546: 'nonalcoholic',
#  547: 'informtion',
#  548: 'proves',
#  549: 'categoryinformation',
#  550: 'migara',
#  551: 'knows',
#  552: 'patient',
#  553: 'forts',
#  554: 'peers',
#  555: 'disciplinary',
#  556: 'bhagwadgita',
#  557: 'refueling',
#  558: 'ropeway',
#  559: 'bloodbath',
#  560: 'viratnagardharan',
#  561: 'writes',
#  562: 'glimpse',
#  563: 'vachanas',
#  564: 'synoptic',
#  565: 'positions',
#  566: 'oak',
#  567: 'nonhomologous',
#  568: 'verticalshort',
#  569: 'creatures',
#  570: 'banita',
#  571: 'distinguished',
#  572: 'quoted',
#  573: 'audio',
#  574: 'acclaim',
#  575: 'projection',
#  576: 'fanaticism',
#  577: 'museum',
#  578: 'innings',
#  579: 'radcliffe',
#  580: 'failures',
#  581: 'diagnose',
#  582: 'buddhodana',
#  583: 'faster',
#  584: 'bijnore',
#  585: 'brown',
#  586: 'remedied',
#  587: 'sharif',
#  588: 'average',
#  589: 'technically',
#  590: 'malla',
#  591: 'house',
#  592: 'jammu',
#  593: 'bhagavad',
#  594: 'selective',
#  595: 'colonise',
#  596: 'beehari',
#  597: 'buddhism',
#  598: 'definite',
#  599: 'lt',
#  600: 'insight',
#  601: 'jambu',
#  602: 'warren',
#  603: 'jharia',
#  604: 'premedieval',
#  605: 'gods',
#  606: 'borivali',
#  607: 'ground',
#  608: 'fauj',
#  609: 'flame',
#  610: '77',
#  611: 'advisory',
#  612: '97',
#  613: 'acreage',
#  614: 'vyasa',
#  615: 'utilise',
#  616: 'taxed',
#  617: 'draft',
#  618: 'judged',
#  619: 'assassinations',
#  620: 'leg',
#  621: 'tied',
#  622: 'dealing',
#  623: 'jyotimt',
#  624: 'closes',
#  625: 'retrofitting',
#  626: 'gameseven',
#  627: 'authoritative',
#  628: 'injustice',
#  629: 'nudity',
#  630: 'ekta',
#  631: 'coverd',
#  632: 'gloating',
#  633: 'prostitution',
#  634: 'occurring',
#  635: 'stumbling',
#  636: 'confirming',
#  637: 'shelves',
#  638: 'hammered',
#  639: 'vial',
#  640: 'pn',
#  641: 'struggle',
#  642: 'dmakudha',
#  643: 'blue',
#  644: 'without',
#  645: 'mental',
#  646: 'ate',
#  647: 'council',
#  648: 'specifics',
#  649: 'diabetic',
#  650: 'idea',
#  651: 'adoptation',
#  652: 'meerbai',
#  653: 'untruth',
#  654: 'disciple',
#  655: 'capsleeved',
#  656: 'dominating',
#  657: 'stern',
#  658: 'forget',
#  659: '80',
#  660: 'salas',
#  661: 'integrate',
#  662: 'legislative',
#  663: 'revealed',
#  664: 'washington',
#  665: 'relics',
#  666: 'favour',
#  667: '200001',
#  668: 'juxtaposition',
#  669: '20008',
#  670: 'omar',
#  671: 'dev',
#  672: 'boxoffice',
#  673: 'waist',
#  674: 'theyhomo',
#  675: 'snow',
#  676: 'permorning',
#  677: 'fellowworkers',
#  678: 'astir',
#  679: 'anarchists',
#  680: 'footing',
#  681: 'kneaded',
#  682: 'limits',
#  683: 'solicitor',
#  684: 'indonesian',
#  685: 'pet',
#  686: 'breathing',
#  687: 'fits',
#  688: 'chechnya',
#  689: 'accidentally',
#  690: 'aryans',
#  691: '3775',
#  692: 'cleanest',
#  693: 'flora',
#  694: 'disinterest',
#  695: 'dd',
#  696: 'jungle',
#  697: 'wielding',
#  698: 'dams',
#  699: 'g8',
#  700: 'violated',
#  701: 'absolute',
#  702: 'homelike',
#  703: 'inserted',
#  704: 'jaiselmer',
#  705: 'ceremonies',
#  706: 'respectivelyduring',
#  707: 'abrogation',
#  708: 'delineating',
#  709: 'patients',
#  710: 'mg',
#  711: 'gomti',
#  712: 'sub',
#  713: 'pretext',
#  714: 'climbdown',
#  715: 'bags',
#  716: 'whereas',
#  717: 'sculptures',
#  718: 'selection',
#  719: 'alter',
#  720: '2755620',
#  721: 'twilight',
#  722: 'bust',
#  723: 'untouchability',
#  724: 'rapport',
#  725: 'mile',
#  726: 'agreement',
#  727: 'gasses',
#  728: 'mochi',
#  729: 'separatist',
#  730: 'disconnected',
#  731: 'forthcoming',
#  732: 'wedge',
#  733: 'cheapest',
#  734: 'supremacy',
#  735: 'apprehension',
#  736: 'bonfires',
#  737: 'dangers',
#  738: 'freeze',
#  739: 'lotus',
#  740: 'pakistans',
#  741: 'swimmer',
#  742: 'reached',
#  743: 'pervading',
#  744: 'napping',
#  745: 'hbo',
#  746: 'mangaliveda',
#  747: 'telescopes',
#  748: 'adjective',
#  749: 'starting',
#  750: 'delhihe',
#  751: 'americaafrica',
#  752: 'ladies',
#  753: 'peacocks',
#  754: 'uddhav',
#  755: 'aananthi',
#  756: 'olds',
#  757: 'structured',
#  758: 'cars',
#  759: 'swear',
#  760: 'jail',
#  761: 'wellbeing',
#  762: 'spoke',
#  763: 'ducks',
#  764: 'shoneys',
#  765: 'assigned',
#  766: 'kaali',
#  767: 'slopy',
#  768: '13',
#  769: 'forgivable',
#  770: 'empirical',
#  771: '195960',
#  772: 'charging',
#  773: 'teressa',
#  774: 'esteem',
#  775: 'biggest',
#  776: 'someday',
#  777: 'patterns',
#  778: 'line',
#  779: 'directed',
#  780: 'texttospeech',
#  781: 'commons',
#  782: 'stringed',
#  783: 'german',
#  784: 'attained',
#  785: 'them',
#  786: 'unifying',
#  787: '1857',
#  788: 'accumulating',
#  789: 'fuel',
#  790: 'clean',
#  791: 'devakoshtha',
#  792: 'revolutionary',
#  793: 'noninvasive',
#  794: 'overflow',
#  795: 'midfebruary',
#  796: 'allaehi',
#  797: 'saddhmam',
#  798: 'rabbit',
#  799: 'hobbs',
#  800: 'sethi',
#  801: 'bestow',
#  802: 'antyajas',
#  803: 'northeast',
#  804: '1984',
#  805: 'arabs',
#  806: 'manuyears',
#  807: 'sanjay',
#  808: 'virashaiva',
#  809: '75000',
#  810: 'thanjavur',
#  811: 'efficiently',
#  812: 'commenting',
#  813: 'fantastic',
#  814: 'sanga',
#  815: 'mutiny',
#  816: 'in',
#  817: 'reflecting',
#  818: 'accusing',
#  819: 'difficulties',
#  820: 'heartily',
#  821: 'puns',
#  822: 'lalone',
#  823: 'sirajullughat',
#  824: 'intestinal',
#  825: 'happened',
#  826: '04',
#  827: 'handset',
#  828: 'geographical',
#  829: 'contracted',
#  830: 'pearl',
#  831: 'drove',
#  832: 'multan',
#  833: 'yajus',
#  834: '1602',
#  835: 'discomfort',
#  836: 'nationalism',
#  837: 'nairobi',
#  838: 'muscle',
#  839: 'rank',
#  840: 'directives',
#  841: 'authorities',
#  842: 'affronts',
#  843: 'downtrodden',
#  844: '253',
#  845: 'availed',
#  846: 'sanchar',
#  847: 'peelibheet',
#  848: 'hosiery',
#  849: 'clouds',
#  850: 'principles',
#  851: 'bengal',
#  852: 'scientist',
#  853: 'formality',
#  854: 'city',
#  855: 'survival',
#  856: 'criticisms',
#  857: 'try',
#  858: 'asha',
#  859: 'degenerative',
#  860: 'books',
#  861: 'via',
#  862: 'nasik',
#  863: 'rude',
#  864: '20',
#  865: 'fewer',
#  866: 'shree',
#  867: 'sankara',
#  868: 'outlawed',
#  869: 'violates',
#  870: 'female',
#  871: 'cornered',
#  872: 'fate',
#  873: 'patriot',
#  874: 'stagger',
#  875: 'careful',
#  876: 'concentration',
#  877: 'naked',
#  878: 'maintained',
#  879: 'find',
#  880: 'emotional',
#  881: 'presentation',
#  882: 'consist',
#  883: 'forceful',
#  884: 'lama',
#  885: 'clinging',
#  886: 'openness',
#  887: 'till',
#  888: 'siren',
#  889: 'gather',
#  890: 'proteins',
#  891: 'milestone',
#  892: 'namely',
#  893: 'strove',
#  894: 'doodle',
#  895: 'tokyo',
#  896: 'credit',
#  897: 'under',
#  898: 'islams',
#  899: 'mattered',
#  900: 'staff',
#  901: 'refuge',
#  902: 'thrusts',
#  903: 'addition',
#  904: 'raj',
#  905: 'utilising',
#  906: 'rigvedamahabharatramayana',
#  907: 'imagery',
#  908: 'misleading',
#  909: 'whether',
#  910: 'sacrifices',
#  911: 'mistake',
#  912: 'aloud',
#  913: 'veracity',
#  914: 'useless',
#  915: 'colliery',
#  916: 'jobcentre',
#  917: 'mamandur',
#  918: 'durand',
#  919: 'prorogued',
#  920: 'weak',
#  921: 'undermined',
#  922: 'third',
#  923: 'calcutta',
#  924: 'might',
#  925: 'renascent',
#  926: 'greatness',
#  927: 'favorite',
#  928: 'alltime',
#  929: 'divine',
#  930: 'converges',
#  931: 'wellfocused',
#  932: 'pearls',
#  933: 'thesis',
#  934: 'ablaze',
#  935: 'pakhtoon',
#  936: 'titht',
#  937: 'software',
#  938: 'jogging',
#  939: 'awaits',
#  940: 'hebrew',
#  941: 'inequality',
#  942: 'complained',
#  943: 'bharathpur',
#  944: 'lifesaving',
#  945: 'gumline',
#  946: 'necessitating',
#  947: 'dunespronounced',
#  948: 'uchaaran',
#  949: 'vasallams',
#  950: 'arguing',
#  951: 'supportedwyswyg',
#  952: 'approach',
#  953: 'basava',
#  954: '394',
#  955: '131',
#  956: 'disaffectiona',
#  957: 'absorb',
#  958: 'shantiparva',
#  959: 'vaccine',
#  960: 'everything',
#  961: 'layer',
#  962: 'submerged',
#  963: 'nd',
#  964: 'definitely',
#  965: 'parient',
#  966: 'summoned',
#  967: 'domiciliary',
#  968: 'crossover',
#  969: 'superintendent',
#  970: 'cartoonist',
#  971: 'hysterical',
#  972: 'gently',
#  973: 'hints',
#  974: '121a',
#  975: 'coordination',
#  976: 'cng',
#  977: 'furniture',
#  978: 'rightful',
#  979: '2050',
#  980: 'resorting',
#  981: 'roja',
#  982: 'surplus',
#  983: 'vigilange',
#  984: 'compliment',
#  985: 'ruined',
#  986: 'friday',
#  987: 'rural',
#  988: 'zail',
#  989: 'malayalam',
#  990: 'against',
#  991: 'shutting',
#  992: 'coffee',
#  993: 'everybody',
#  994: 'egypt',
#  995: 'payyanur',
#  996: 'nabha',
#  997: 'mocking',
#  998: '226',
#  999: 'phibi',
#  ...}

# %%
print(f"Number of sentences: {len(hindi_sentences)}")
print(f"Number of sentences: {len(english_sentences)}")
# Out:
# Number of sentences: 9907
# Number of sentences: 9907

# %%
def is_valid_tokens (sentence, vocab) :
    return all(token in vocab for token in sentence.split())
    
def is_valid_length (sentence, max_sequence_length) :
    return len(sentence.split()) < (max_sequence_length - 1) # need to re-add the end token so leaving 1 space
    
valid_sentence_indices = [
    index for index, (hindi_sentence, english_sentence) in enumerate(zip(hindi_sentences, english_sentences))
    if is_valid_length(hindi_sentence, max_sequence_length)
    and is_valid_length(english_sentence, max_sequence_length) 
    and is_valid_tokens(hindi_sentence, hindi_vocab)
]

print(f"Number of sentences: {len(hindi_sentences)}")
print(f"Number of valid sentences: {len(valid_sentence_indices)}")
# Out:
# Number of sentences: 9907
# Number of valid sentences: 9905

# %%
hindi_sentences = [hindi_sentences[i] for i in valid_sentence_indices]
english_sentences = [english_sentences[i] for i in valid_sentence_indices]
print(len(hindi_sentences))
print(len(english_sentences))
# Out:
# 9905
# 9905

# %%
class TextDataset (Dataset):
    def __init__(self, english_sentences, hindi_sentences):
        self.english_sentences = english_sentences
        self.hindi_sentences = hindi_sentences
    
    def __len__(self) :
        return len(self.english_sentences)
    
    def __getitem__(self, idx):
        return self.english_sentences[idx], self.hindi_sentences[idx]

# %%
dataset = TextDataset(english_sentences, hindi_sentences)
len(dataset)
# Out:
# 9905

# %% [markdown]
# ## Training the model Model

# %%
hn_vocab_size = len(hindi_vocab)
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
transformer = Transformer(
    d_model,
    ffn_hidden,
    num_heads, 
    drop_prob, 
    num_layers, 
    max_sequence_length, 
    hn_vocab_size,
    english_to_index, 
    hindi_to_index,
    START_TOKEN, 
    END_TOKEN, 
    PADDING_TOKEN)
# Out:
# torch.Size([15844, 256])
# torch.Size([18301, 256])

# %%
criterian = nn.CrossEntropyLoss(ignore_index=hindi_to_index[PADDING_TOKEN],
                                reduction= 'none')
# When computing the loss, we are ignoring cases when the label is the padding token
for params in transformer.parameters():
    if params.dim() > 1:
        nn.init.xavier_uniform_(params)
        
optim = torch.optim.Adam(transformer.parameters(), lr=1e-4)

# %%
NEG_INFTY = -1e9

def create_masks(eng_batch, hn_batch):
    num_sentences = len(eng_batch)
    look_ahead_mask = torch.full([max_sequence_length, max_sequence_length] , True)
    look_ahead_mask = torch.triu(look_ahead_mask, diagonal=1)
    encoder_padding_mask = torch.full([num_sentences, max_sequence_length, max_sequence_length] , False)
    decoder_padding_mask_self_attention = torch.full([num_sentences, max_sequence_length, max_sequence_length] , False)
    decoder_padding_mask_cross_attention = torch.full([num_sentences, max_sequence_length, max_sequence_length] , False)
    
    for idx in range(num_sentences):
        eng_sentence_length, hn_sentence_length = len(eng_batch[idx]), len(hn_batch[idx])
        eng_words_to_padding_mask = np.arange(eng_sentence_length + 1, max_sequence_length)
        hn_words_to_padding_mask = np.arange(hn_sentence_length + 1, max_sequence_length)
        encoder_padding_mask[idx, :, eng_words_to_padding_mask] = True
        encoder_padding_mask[idx, eng_words_to_padding_mask, :] = True
        decoder_padding_mask_self_attention[idx, :, hn_words_to_padding_mask] = True
        decoder_padding_mask_self_attention[idx, hn_words_to_padding_mask, :] = True
        decoder_padding_mask_cross_attention[idx,:, eng_words_to_padding_mask] = True
        decoder_padding_mask_cross_attention[idx, hn_words_to_padding_mask, :] = True
    
    encoder_self_attention_mask = torch.where(encoder_padding_mask, NEG_INFTY, 0)
    decoder_self_attention_mask = torch.where(look_ahead_mask + decoder_padding_mask_self_attention, NEG_INFTY, 0)
    decoder_cross_attention_mask = torch.where(decoder_padding_mask_cross_attention, NEG_INFTY, 0)
    # print f" encoder self _attention mask (encoder_self _attention mask size(l}: (encoder self_attention_maskl, :10, :101")
    # print (f"decoder_self_attention mask {decoder_self_attention_mask.size()}: {decoder_self_attention_mask[0, :10, :10]}")
    # print(f" decoder_cross_attention_mask {decoder_cross_attention_mask.size()}: {decoder_cross_attention_mask[0, :10, : 10]}")
    return encoder_self_attention_mask, decoder_self_attention_mask, decoder_cross_attention_mask

# %%
# transformer.train()
transformer.to(device)
total_loss = 0
num_epochs = 10

for epoch in range(num_epochs):
    print (f"Epoch {epoch}")
    iterator = iter(train_loader)
    for batch_num, batch in enumerate(iterator):
        transformer.train()
        eng_batch, hn_batch = batch
        encoder_self_attention_mask, decoder_self_attention_mask, decoder_cross_attention_mask = create_masks(eng_batch, hn_batch)
        optim.zero_grad()
        hn_predictions = transformer(eng_batch,
                                     hn_batch,
                                     encoder_self_attention_mask.to(device), 
                                     decoder_self_attention_mask.to(device), 
                                     decoder_cross_attention_mask.to(device), 
                                     enc_start_token=False, 
                                     enc_end_token=False, 
                                     dec_start_token=True,
                                     dec_end_token=True)
        labels = transformer.decoder.sentence_embedding.batch_tokenize(hn_batch, start_token=False, end_token=True)
        loss = criterian(
            hn_predictions.view(-1, hn_vocab_size).to(device), 
            labels.view(-1).to(device)
        ).to(device)

        valid_indicies = torch.where(labels.view(-1) == hindi_to_index[PADDING_TOKEN], False, True)
        loss = loss.sum() / valid_indicies.sum()
        loss.backward()
        optim.step()
        #train_losses.append(loss.item())
        if batch_num % 100 == 0:
            print(f"Iteration {batch_num} : {loss.item()}")
            print(f"English: {eng_batch[0]}")
            print(f"Hindi Translation: {hn_batch[0]}")
            hn_sentence_predicted = torch.argmax(hn_predictions[0], axis=1)
            predicted_sentence = ""
            for idx in hn_sentence_predicted:
                if idx == hindi_to_index [END_TOKEN]:
                    break
                predicted_sentence += index_to_hindi[idx.item()] + " " # Add a space after each word
            predicted_sentence = predicted_sentence.strip() # Remove the trailing space

            
            transformer.eval()
            hn_sentence = ("",)
            eng_sentence = ("put folder in the bin",)
            for word_counter in range(max_sequence_length):
                encoder_self_attention_mask, decoder_self_attention_mask, decoder_cross_attention_mask = create_masks(eng_sentence, hn_sentence)
                predictions = transformer(eng_sentence,
                                          hn_sentence,
                                          encoder_self_attention_mask.to(device), 
                                          decoder_self_attention_mask.to(device), 
                                          decoder_cross_attention_mask.to(device), 
                                          enc_start_token=False, 
                                          enc_end_token=False, 
                                          dec_start_token=True,
                                          dec_end_token=True)
                
                next_token_prob_distribution = predictions[0][word_counter]# not actual probs
                next_token_index = torch.argmax(next_token_prob_distribution).item()
                next_token = index_to_hindi[next_token_index]
                hn_sentence = (hn_sentence[0] + next_token + " ", ) # Add a space after each word
                if next_token == END_TOKEN:
                    break
            hn_sentence = (hn_sentence[0].strip(),) # Remove the trailing space
            print(f"Evaluation translation (put folder in the bin) : {hn_sentence}")
            print("--------------------------------------------------------------------")
# Out:
# Epoch 0
# Iteration 0 : 9.814488410949707
# English: it is easy to add 5 to 10
# Hindi Translation: पाँच से दस को जोड़ना बहुत आसान है।
# Evaluation translation (put folder in the bin) : ('<END>',)
# --------------------------------------------------------------------
# Iteration 100 : 7.724740505218506
# English: second major dam in ganga river is tihari dam is under tihari development project and is situated in tihari district of uttarakhand
# Hindi Translation: गंगा पर निर्मित दूसरा प्रमुख बाँध टिहरी बाँध टिहरी विकास परियोजना का एक प्राथमिक बाँध है जो उत्तराखंड प्रान्त के टिहरी जिले में स्थित है।
# Evaluation translation (put folder in the bin) : ('<END>',)
# --------------------------------------------------------------------
# Epoch 1
# Iteration 0 : 7.123497486114502
# English: akra kay or about army
# Hindi Translation: अग्रकय या प्रतिक्रियाशील सैन्य कार्रवाई
# Evaluation translation (put folder in the bin) : ('<END>',)
# --------------------------------------------------------------------
# Iteration 100 : 7.007385730743408
# English: luckily the genetic testing proved
# Hindi Translation: भाग्य से आनुवंशिक टेस्ट ने साबित किया
# Evaluation translation (put folder in the bin) : ('<END>',)
# --------------------------------------------------------------------
# Epoch 2
# Iteration 0 : 6.8240156173706055
# English: i like both science and math
# Hindi Translation: मुझे विज्ञान और गणित दोनों पसंद हैं।
# Evaluation translation (put folder in the bin) : ('<END>',)
# --------------------------------------------------------------------
# Iteration 100 : 7.033634185791016
# English: in that Tears in my eyes there were mixture of present pakistan and bangladesh
# Hindi Translation: उस समय पाकिस्तान में वर्तमान पाकिस्तान और बांग्लादेश दोनों सम्मिलित थे ।
# Evaluation translation (put folder in the bin) : ('मैं मैं <END>',)
# --------------------------------------------------------------------
# Epoch 3
# Iteration 0 : 6.942835807800293
# English: bring him in
# Hindi Translation: उसको अंदर ले आओ।
# Evaluation translation (put folder in the bin) : ('मैं मैं <END>',)
# --------------------------------------------------------------------
# Iteration 100 : 6.903749942779541
# English: after his arrest in january 1932 subhas chandra was lodged in a small jail in seoni an obscure place in central provinces
# Hindi Translation: जनवरी   में  गिरफ्तारी के बाद सुभाष चन्द्र को मध्य प्रांत के एक अनजान स्थान सिवनी की छोटीसी जेल में रखा गया
# Evaluation translation (put folder in the bin) : ('मैं मैं <END>',)
# --------------------------------------------------------------------
# Epoch 4
# Iteration 0 : 6.859203815460205
# English: what information you can expect to have to help you reach decisions about your care including informtion such as appropriate tests before the baby is born lrb antenatal tests rrb
# Hindi Translation:
# Evaluation translation (put folder in the bin) : ('मैं मैं <END>',)
# --------------------------------------------------------------------
# Iteration 100 : 6.533653259277344
# English: my friends celebrated my birthday
# Hindi Translation: मेरे दोस्तों ने मेरा जन्मदिन मनाया।
# Evaluation translation (put folder in the bin) : ('मैं मैं में में में <END>',)
# --------------------------------------------------------------------
# Epoch 5
# Iteration 0 : 6.4622721672058105
# English: to allay fears about the ill effects of donating blood he points to the fact that despite having done it 50 times he has no major ailment
# Hindi Translation: वे रक्तदान के  कुप्रभावों  की आशंका को दूर करने के लिए बताते हैं कि  बार रक्तदान करने के बावजूद उन्हें कोई बड़ी बीमारी नहीं ही है
# Evaluation translation (put folder in the bin) : ('मैं मैं <END>',)
# --------------------------------------------------------------------
# Iteration 100 : 6.440803527832031
# English: chandigarh just when the congress had begun to make corruption in the akali dalbjp ranks its poll plank the plank got shaky
# Hindi Translation: चंड़ीगढेः गुटबाजी से त्रस्त कांग्रेस ने अकाली दलभाजपा सरकार में व्याप्त भ्रष्टाचार को चुनावी मुद्दा बनाया तभी यह मामल उलटा पड़े गया
# Evaluation translation (put folder in the bin) : ('मैं मैं एक <END>',)
# --------------------------------------------------------------------
# Epoch 6
# Iteration 0 : 6.298130989074707
# English: there is no chance of the hindu and muslim religion one and the same
# Hindi Translation: इस्लाम में हिन्दू धर्म के समान समय के परिपत्र होने की अवधारणा नहीं है।
# Evaluation translation (put folder in the bin) : ('मैं मैं बहुत <END>',)
# --------------------------------------------------------------------
# Iteration 100 : 6.435568332672119
# English: as for me i am satisfied
# Hindi Translation: मैं तो संतुष्ट हूँ।
# Evaluation translation (put folder in the bin) : ('मैं मैं बहुत नहीं <END>',)
# --------------------------------------------------------------------
# Epoch 7
# Iteration 0 : 6.2993550300598145
# English: in spite of all this there is a danger to existence of ganga
# Hindi Translation: इतना सबकुछ होने के बावजूद गंगा के अस्तित्व पर संकट के बादल छाए हुए हैं।
# Evaluation translation (put folder in the bin) : ('मैं मैं एक बहुत नहीं है। <END>',)
# --------------------------------------------------------------------
# Iteration 100 : 6.356875419616699
# English: she said to herself i am very happy
# Hindi Translation: उसने अपने आप से कहा मैं बहुत खुश हूँ
# Evaluation translation (put folder in the bin) : ('मैं मैं एक बहुत <END>',)
# --------------------------------------------------------------------
# Epoch 8
# Iteration 0 : 5.997310161590576
# English: the summary general court martial consists of not less than three officers
# Hindi Translation: संक्षिप्त सामान्य सेना न्यायालय में कम से कम तीन अधिकारी होते हैं
# Evaluation translation (put folder in the bin) : ('मैं मैं एक नहीं है। <END>',)
# --------------------------------------------------------------------
# Iteration 100 : 6.123577117919922
# English: toudaiji is the bigger of the two temples
# Hindi Translation: उन दो मंदिरों में तोदाइजी बड़ा वाला है।
# Evaluation translation (put folder in the bin) : ('मैं एक बहुत नहीं है। <END>',)
# --------------------------------------------------------------------
# Epoch 9
# Iteration 0 : 6.071846961975098
# English: the constituent assembly accomplished the tremendous task of framing the constitution in less than three years
# Hindi Translation: संविधान सभा ने संविधान बनाने का भारी काम तीन वर्ष से कम समय में पूरा किया
# Evaluation translation (put folder in the bin) : ('मैं एक एक नहीं है। <END>',)
# --------------------------------------------------------------------
# Iteration 100 : 6.002129554748535
# English: we drink our tea with sugar
# Hindi Translation: हम चाय चीनी डालकर पीते हैं।
# Evaluation translation (put folder in the bin) : ('मैं एक बहुत नहीं है। <END>',)
# --------------------------------------------------------------------

# %%
def translate(eng_sentence):
    eng_sentence = (eng_sentence, )
    hn_sentence = ("",)
    for word_counter in range(max_sequence_length):
        encoder_self_attention_mask, decoder_self_attention_mask, decoder_cross_attention_mask = create_masks(eng_sentence, hn_sentence)
        predictions = transformer(eng_sentence,
                                  hn_sentence, 
                                  encoder_self_attention_mask.to(device), 
                                  decoder_self_attention_mask.to(device),
                                  decoder_cross_attention_mask.to(device), 
                                  enc_end_token=False, 
                                  dec_start_token=True, 
                                  dec_end_token=False)
        
        next_token_prob_distribution = predictions[0][word_counter]
        next_token_index = torch.argmax(next_token_prob_distribution).item()
        next_token = index_to_hindi[next_token_index]
        hn_sentence = (hn_sentence[0] + next_token + " ", )
        if next_token == END_TOKEN:
            break
    return hn_sentence[0]

# %%
translation = translate("He exist there")
print(translation)
# Out:
# मैं <END>
